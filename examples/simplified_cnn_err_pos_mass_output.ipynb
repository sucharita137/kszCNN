# %%
import sys
import os
import numpy as np
import torch
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import train_test_split
from scipy.stats import pearsonr

# %%
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from kszcnn.simplified_cnn_err_pos_mass import *

# %%
np.random.seed(SEED)
torch.manual_seed(SEED)

# %%
#  1. Load grids
grid_train, grid_test = memmap_grid_slices(
    GRID_FILE, [TRAIN_REAL_IDX, TEST_REAL_IDX]
)

print("Grid shapes:", grid_train.shape, grid_test.shape)
# Out:
# Grid shapes: (128, 128, 128) (128, 128, 128)

# %%
# 2. Smooth density
delta_train = smooth_density_kspace(grid_train, SMOOTH_SCALE)
delta_test  = smooth_density_kspace(grid_test, SMOOTH_SCALE)

# %%
#  3. Normalize
mean = delta_train.mean()
std  = delta_train.std() + 1e-12

delta_train = (delta_train - mean) / std
delta_test  = (delta_test - mean) / std

# %%
# 4. Load halos
pos_tr, vel_tr, mass_tr = load_halos(TRAIN_HALO_FILE)
pos_te, vel_te, mass_te = load_halos(TEST_HALO_FILE)

pos_tr = redshift_err(pos_tr, sigma_z=1e-4)
pos_te = redshift_err(pos_te, sigma_z=1e-4)


print("Halos:", len(pos_tr), len(pos_te))
# Out:
# Halos: 20817 21205

# %%
#  5. Dataset 
rng = np.random.RandomState(SEED)
train_ds_full = HaloDataset(
    delta_train,
    pos_tr,
    vel_tr,
    mass_tr,
    mass_cut=MASS_CUT, max_n=MAX_HALOS,
    rng=rng
)

test_ds = HaloDataset(
    delta_test,
    pos_te,
    vel_te,
    mass_te,
    mass_cut=MASS_CUT, max_n=MAX_HALOS,
    rng=rng
)
# Out:
# Selected halos: 547
# Selected halos: 569

# %%
#  6. Linear baseline 
vlin_test = compute_vlin_from_density(
    grid_test,R_smooth=SMOOTH_SCALE
)

vlin_baseline = vlin_at_halos(vlin_test, test_ds.pos)

rho_vlin = pearsonr(test_ds.vz, vlin_baseline)[0]

print("Linear theory correlation:", rho_vlin)
# Out:
# Linear theory correlation: 0.8239114

# %%
#7. Train / validation
idxs = np.arange(len(train_ds_full))

tr_idx, val_idx = train_test_split(
    idxs,
    test_size=0.2,
    random_state=SEED
)

tr_ds  = Subset(train_ds_full, tr_idx)
val_ds = Subset(train_ds_full, val_idx)

# %%
#  8. Loaders
tr_loader = DataLoader(tr_ds, batch_size=BATCH, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH)
te_loader  = DataLoader(test_ds, batch_size=BATCH)

# %%
#  9. Normalize velocity
y_train = np.array([train_ds_full[i][1] for i in tr_idx])

y_mean = y_train.mean()
y_std  = y_train.std() + 1e-12

print("Velocity mean/std:", y_mean, y_std)
# Out:
# Velocity mean/std: -1.0862699 105.11467

# %%
model = CNN().to(DEVICE)

# %%
train_model(
        model, tr_loader, val_loader, y_mean, y_std
    )
# Out:
# Epoch 1: Train=3.614e-01 | Val=8.251e-01
# Epoch 2: Train=3.123e-01 | Val=7.598e-01
# Epoch 3: Train=2.925e-01 | Val=7.673e-01
# Epoch 4: Train=2.975e-01 | Val=8.896e-01
# Epoch 5: Train=3.080e-01 | Val=7.752e-01
# Epoch 6: Train=2.836e-01 | Val=7.848e-01
# Epoch 7: Train=2.733e-01 | Val=6.895e-01
# Epoch 8: Train=2.453e-01 | Val=7.214e-01
# Epoch 9: Train=2.407e-01 | Val=6.148e-01
# Epoch 10: Train=2.343e-01 | Val=6.362e-01
# Epoch 11: Train=2.256e-01 | Val=6.702e-01
# Epoch 12: Train=2.088e-01 | Val=7.305e-01
# Epoch 13: Train=2.320e-01 | Val=6.334e-01
# Epoch 14: Train=2.124e-01 | Val=7.948e-01
# Epoch 15: Train=2.437e-01 | Val=6.444e-01
# Epoch 16: Train=2.116e-01 | Val=6.498e-01
# Epoch 17: Train=2.056e-01 | Val=5.200e-01
# Epoch 18: Train=1.982e-01 | Val=7.432e-01
# Epoch 19: Train=1.994e-01 | Val=5.382e-01
# Epoch 20: Train=1.928e-01 | Val=5.104e-01
# Epoch 21: Train=1.811e-01 | Val=5.264e-01
# Epoch 22: Train=1.754e-01 | Val=5.070e-01
# Epoch 23: Train=1.756e-01 | Val=5.185e-01
# Epoch 24: Train=1.673e-01 | Val=5.185e-01
# Epoch 25: Train=1.698e-01 | Val=6.680e-01
# Epoch 26: Train=1.800e-01 | Val=5.327e-01
# Epoch 27: Train=1.664e-01 | Val=5.651e-01
# Epoch 28: Train=1.699e-01 | Val=5.060e-01
# Epoch 29: Train=1.915e-01 | Val=5.328e-01
# Epoch 30: Train=1.720e-01 | Val=4.331e-01
# Epoch 31: Train=1.604e-01 | Val=4.460e-01
# Epoch 32: Train=1.605e-01 | Val=5.487e-01
# Epoch 33: Train=1.483e-01 | Val=4.412e-01
# Epoch 34: Train=1.495e-01 | Val=8.102e-01
# Epoch 35: Train=1.626e-01 | Val=6.658e-01
# Epoch 36: Train=1.645e-01 | Val=4.906e-01
# Epoch 37: Train=1.468e-01 | Val=4.894e-01
# Epoch 38: Train=1.477e-01 | Val=4.676e-01
# Epoch 39: Train=1.667e-01 | Val=4.458e-01
# Epoch 40: Train=1.509e-01 | Val=6.558e-01
# Epoch 41: Train=1.545e-01 | Val=5.609e-01
# Epoch 42: Train=1.566e-01 | Val=4.367e-01
# Epoch 43: Train=1.309e-01 | Val=5.135e-01
# Epoch 44: Train=1.245e-01 | Val=4.308e-01
# Epoch 45: Train=1.279e-01 | Val=5.054e-01
# Epoch 46: Train=1.291e-01 | Val=5.035e-01
# Epoch 47: Train=1.157e-01 | Val=4.197e-01
# Epoch 48: Train=1.138e-01 | Val=4.633e-01
# Epoch 49: Train=1.329e-01 | Val=5.158e-01
# Epoch 50: Train=1.290e-01 | Val=4.719e-01
# Epoch 51: Train=1.166e-01 | Val=4.144e-01
# Epoch 52: Train=1.147e-01 | Val=5.072e-01
# Epoch 53: Train=1.208e-01 | Val=5.771e-01
# Epoch 54: Train=1.206e-01 | Val=4.330e-01
# Epoch 55: Train=1.198e-01 | Val=5.039e-01
# Epoch 56: Train=1.182e-01 | Val=4.222e-01
# Epoch 57: Train=1.158e-01 | Val=4.631e-01
# Epoch 58: Train=1.112e-01 | Val=5.517e-01
# Epoch 59: Train=1.054e-01 | Val=5.362e-01
# Epoch 60: Train=1.058e-01 | Val=6.462e-01
# Epoch 61: Train=1.178e-01 | Val=5.890e-01
# Epoch 62: Train=1.257e-01 | Val=5.204e-01
# Epoch 63: Train=1.373e-01 | Val=5.415e-01
# Epoch 64: Train=1.071e-01 | Val=4.620e-01
# Epoch 65: Train=9.701e-02 | Val=6.124e-01
# Epoch 66: Train=1.184e-01 | Val=4.229e-01
# Epoch 67: Train=1.062e-01 | Val=4.631e-01
# Epoch 68: Train=9.779e-02 | Val=5.002e-01
# Epoch 69: Train=1.041e-01 | Val=4.995e-01
# Epoch 70: Train=1.097e-01 | Val=5.789e-01
# Epoch 71: Train=1.011e-01 | Val=4.746e-01
# Epoch 72: Train=9.260e-02 | Val=4.472e-01
# Epoch 73: Train=8.838e-02 | Val=4.209e-01
# Epoch 74: Train=9.510e-02 | Val=4.612e-01
# Epoch 75: Train=9.791e-02 | Val=4.376e-01
# Epoch 76: Train=8.937e-02 | Val=5.004e-01
# Epoch 77: Train=8.805e-02 | Val=6.172e-01
# Epoch 78: Train=1.045e-01 | Val=4.944e-01
# Epoch 79: Train=7.884e-02 | Val=7.002e-01
# Epoch 80: Train=8.931e-02 | Val=5.081e-01
# Epoch 81: Train=9.858e-02 | Val=5.207e-01
# Epoch 82: Train=7.578e-02 | Val=5.447e-01
# Epoch 83: Train=7.699e-02 | Val=4.757e-01
# Epoch 84: Train=7.823e-02 | Val=5.427e-01
# Epoch 85: Train=8.836e-02 | Val=5.108e-01
# Epoch 86: Train=7.896e-02 | Val=6.662e-01
# Epoch 87: Train=9.264e-02 | Val=4.879e-01
# Epoch 88: Train=1.115e-01 | Val=4.837e-01
# Epoch 89: Train=1.004e-01 | Val=4.821e-01
# Epoch 90: Train=8.274e-02 | Val=4.571e-01
# Epoch 91: Train=8.779e-02 | Val=4.569e-01
# Epoch 92: Train=8.828e-02 | Val=4.862e-01
# Epoch 93: Train=7.379e-02 | Val=5.918e-01
# Epoch 94: Train=8.018e-02 | Val=5.462e-01
# Epoch 95: Train=7.993e-02 | Val=4.805e-01
# Epoch 96: Train=8.182e-02 | Val=5.144e-01
# Epoch 97: Train=8.284e-02 | Val=5.150e-01
# Epoch 98: Train=6.978e-02 | Val=4.874e-01
# Epoch 99: Train=8.028e-02 | Val=4.864e-01
# Epoch 100: Train=6.923e-02 | Val=6.036e-01
# CNN(
#   (conv): Sequential(
#     (0): Conv3d(4, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): GroupNorm(8, 32, eps=1e-05, affine=True)
#     (2): ReLU()
#     (3): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (5): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (6): ReLU()
#     (7): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (9): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (10): ReLU()
#     (11): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (pool): AdaptiveAvgPool3d(output_size=1)
#   (fc): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
evaluate_model(
        model, te_loader, test_ds,
        y_mean, y_std,
        vlin_baseline, rho_vlin
    )
# Out:
# p68 = 48.87841
# p95 = 129.47964
# p99 = 232.62007
# ===== TEST RESULTS =====
# N = 569
# RMSE = 63.701
# RMS(true) = 96.798
# RMS(pred) = 86.453
