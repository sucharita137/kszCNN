# %%
import sys
import os
import numpy as np
import torch
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import train_test_split
from scipy.stats import pearsonr

# %%
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from kszcnn.same_real_cnn_density_group_M import *

# %%
print("SET:", set_name)
print("GRID_FILE:", GRID_FILE)
print("HALO_FILE:", HALO_FILE)
print("REAL_IDX:", REAL_IDX)
# Out:
# SET: 1P_0
# GRID_FILE: /home/sucharita/kszCNN/data/Grids_Mcdm_IllustrisTNG_1P_128_z=0.0.npy
# HALO_FILE: /home/sucharita/kszCNN/data/groups_090_1P_0.hdf5
# REAL_IDX: 0

# %%
np.random.seed(SEED)
torch.manual_seed(SEED)

# %%
#  1. Load grids
grid = memmap_grid_slices(GRID_FILE, [REAL_IDX])[0]

print("Grid shapes:", grid.shape)
# Out:
# Grid shapes: (128, 128, 128)

# %%
# 2. Smooth density
delta = smooth_density_kspace(grid, SMOOTH_SCALE)

# %%
#  3. Normalize
mean = delta.mean()
std  = delta.std() + 1e-12

delta = (delta - mean) / std

# %%
# 4. Load halos
pos, vel, mass = load_halos(HALO_FILE)
feature = load_feature_file(HALO_FILE, feature_type="group_M")
'''
feature_dict = load_feature_file(HALO_FILE)
feature = feature_dict["mass_fof"]  
feature = np.array(feature) 
'''
# Out:
# '\nfeature_dict = load_feature_file(HALO_FILE)\nfeature = feature_dict["mass_fof"]  \nfeature = np.array(feature) \n'

# %%
rng1 = np.random.RandomState(SEED)
rng2 = np.random.RandomState(SEED + 1)

# %%
full_ds_clean = HaloDataset(
    delta, pos, vel,
    mass,
    feature,
    feature_type="group_M",   # or "nsubs"
    mass_cut=MASS_CUT,
    rng=rng1
)
# Out:
# Selected halos: 547

# %%
idxs = np.arange(len(full_ds_clean))

train_idx, test_idx = train_test_split(
    idxs, test_size=0.2, random_state=SEED
)

train_idx, val_idx = train_test_split(
    train_idx, test_size=0.2, random_state=SEED)

# %%
#mask = mass > MASS_CUT
#filtered_feature = feature[mask]

# %%
'''
train_feat = train_feat = filtered_feature[train_idx]

log_feat = np.log10(train_feat + 1e-6)
feat_mean = log_feat.mean()
feat_std = log_feat.std()
'''
# Out:
# '\ntrain_feat = train_feat = filtered_feature[train_idx]\n\nlog_feat = np.log10(train_feat + 1e-6)\nfeat_mean = log_feat.mean()\nfeat_std = log_feat.std()\n'

# %%
pos_all = pos.copy()

pos_all[test_idx] = redshift_err(
    pos_all[test_idx], sigma_z=1e-4)

# %%
full_ds = HaloDataset(
    delta, pos_all, vel, mass,
    feature,
    feature_type="group_M", 
    mass_cut=MASS_CUT,
    rng=rng2
)
# Out:
# Selected halos: 547

# %%
train_ds = Subset(full_ds, train_idx)
val_ds   = Subset(full_ds, val_idx)
test_ds  = Subset(full_ds, test_idx)

# %%
tr_loader = DataLoader(train_ds, batch_size=BATCH, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH)
te_loader  = DataLoader(test_ds, batch_size=BATCH)

# %%
#  9. Normalize velocity
y_train = np.array([full_ds[i][1] for i in train_idx])

y_mean = y_train.mean()
y_std  = y_train.std() + 1e-12

print("Velocity mean/std:", y_mean, y_std)
# Out:
# Velocity mean/std: 0.36430642 107.621216

# %%
#  6. Linear baseline 
vlin_grid = compute_vlin_from_density(
    grid, R_smooth=SMOOTH_SCALE
    )

test_pos = np.array([full_ds.pos[i] for i in test_idx])
true_vz  = full_ds.vz[test_idx]
vlin_baseline = vlin_at_halos(vlin_grid, test_pos)
rho_vlin = np.corrcoef(true_vz, vlin_baseline)[0,1]


print("Linear theory correlation:", rho_vlin)
# Out:
# Linear theory correlation: 0.8811998544715238

# %%
model = CNN().to(DEVICE)

# %%
train_model(
        model, tr_loader, val_loader, y_mean, y_std
    )
# Out:
# Epoch 1: Train=4.931e-01 | Val=6.109e-01
# Epoch 2: Train=3.873e-01 | Val=5.167e-01
# Epoch 3: Train=3.182e-01 | Val=3.411e-01
# Epoch 4: Train=2.792e-01 | Val=3.656e-01
# Epoch 5: Train=2.575e-01 | Val=3.181e-01
# Epoch 6: Train=2.608e-01 | Val=3.317e-01
# Epoch 7: Train=2.343e-01 | Val=3.231e-01
# Epoch 8: Train=2.289e-01 | Val=3.216e-01
# Epoch 9: Train=2.262e-01 | Val=3.837e-01
# Epoch 10: Train=2.422e-01 | Val=3.373e-01
# Epoch 11: Train=2.210e-01 | Val=3.287e-01
# Epoch 12: Train=2.289e-01 | Val=3.352e-01
# Epoch 13: Train=2.165e-01 | Val=3.620e-01
# Epoch 14: Train=2.102e-01 | Val=3.260e-01
# Epoch 15: Train=2.034e-01 | Val=3.248e-01
# Epoch 16: Train=2.051e-01 | Val=3.149e-01
# Epoch 17: Train=2.200e-01 | Val=3.081e-01
# Epoch 18: Train=1.970e-01 | Val=3.266e-01
# Epoch 19: Train=1.925e-01 | Val=3.527e-01
# Epoch 20: Train=1.973e-01 | Val=3.172e-01
# Epoch 21: Train=1.940e-01 | Val=3.967e-01
# Epoch 22: Train=1.933e-01 | Val=3.989e-01
# Epoch 23: Train=1.833e-01 | Val=3.162e-01
# Epoch 24: Train=1.914e-01 | Val=3.661e-01
# Epoch 25: Train=1.960e-01 | Val=3.292e-01
# Epoch 26: Train=1.910e-01 | Val=3.118e-01
# Epoch 27: Train=1.746e-01 | Val=3.569e-01
# Epoch 28: Train=1.661e-01 | Val=3.776e-01
# Epoch 29: Train=1.701e-01 | Val=3.483e-01
# Epoch 30: Train=1.631e-01 | Val=3.315e-01
# Epoch 31: Train=1.715e-01 | Val=3.438e-01
# Epoch 32: Train=1.580e-01 | Val=4.300e-01
# Epoch 33: Train=1.771e-01 | Val=3.529e-01
# Epoch 34: Train=1.534e-01 | Val=3.304e-01
# Epoch 35: Train=1.375e-01 | Val=4.077e-01
# Epoch 36: Train=1.366e-01 | Val=4.676e-01
# Epoch 37: Train=1.735e-01 | Val=4.435e-01
# Epoch 38: Train=1.613e-01 | Val=3.740e-01
# Epoch 39: Train=1.361e-01 | Val=3.847e-01
# Epoch 40: Train=1.442e-01 | Val=4.146e-01
# Epoch 41: Train=1.386e-01 | Val=4.155e-01
# Epoch 42: Train=1.313e-01 | Val=4.297e-01
# Epoch 43: Train=1.245e-01 | Val=3.449e-01
# Epoch 44: Train=1.309e-01 | Val=4.362e-01
# Epoch 45: Train=1.387e-01 | Val=3.914e-01
# Epoch 46: Train=1.325e-01 | Val=4.068e-01
# Epoch 47: Train=1.197e-01 | Val=4.746e-01
# Epoch 48: Train=1.150e-01 | Val=3.746e-01
# Epoch 49: Train=1.135e-01 | Val=3.799e-01
# Epoch 50: Train=1.193e-01 | Val=4.038e-01
# Epoch 51: Train=1.053e-01 | Val=3.679e-01
# Epoch 52: Train=1.254e-01 | Val=3.465e-01
# Epoch 53: Train=1.473e-01 | Val=3.611e-01
# Epoch 54: Train=1.306e-01 | Val=3.938e-01
# Epoch 55: Train=1.238e-01 | Val=3.686e-01
# Epoch 56: Train=1.314e-01 | Val=3.921e-01
# Epoch 57: Train=1.165e-01 | Val=3.938e-01
# Epoch 58: Train=1.138e-01 | Val=4.256e-01
# Epoch 59: Train=1.019e-01 | Val=4.859e-01
# Epoch 60: Train=9.609e-02 | Val=4.023e-01
# Epoch 61: Train=1.011e-01 | Val=3.830e-01
# Epoch 62: Train=1.184e-01 | Val=3.914e-01
# Epoch 63: Train=8.884e-02 | Val=4.535e-01
# Epoch 64: Train=8.964e-02 | Val=4.586e-01
# Epoch 65: Train=1.081e-01 | Val=3.682e-01
# Epoch 66: Train=9.989e-02 | Val=4.741e-01
# Epoch 67: Train=9.596e-02 | Val=4.894e-01
# Epoch 68: Train=8.423e-02 | Val=4.642e-01
# Epoch 69: Train=7.538e-02 | Val=4.985e-01
# Epoch 70: Train=8.355e-02 | Val=4.300e-01
# Epoch 71: Train=8.501e-02 | Val=4.465e-01
# Epoch 72: Train=8.910e-02 | Val=6.018e-01
# Epoch 73: Train=9.499e-02 | Val=6.331e-01
# Epoch 74: Train=9.354e-02 | Val=4.920e-01
# Epoch 75: Train=8.247e-02 | Val=4.507e-01
# Epoch 76: Train=6.954e-02 | Val=4.988e-01
# Epoch 77: Train=1.122e-01 | Val=4.029e-01
# Epoch 78: Train=1.134e-01 | Val=3.732e-01
# Epoch 79: Train=9.409e-02 | Val=4.742e-01
# Epoch 80: Train=8.617e-02 | Val=4.362e-01
# Epoch 81: Train=8.642e-02 | Val=4.234e-01
# Epoch 82: Train=6.210e-02 | Val=4.435e-01
# Epoch 83: Train=7.357e-02 | Val=4.744e-01
# Epoch 84: Train=7.787e-02 | Val=4.964e-01
# Epoch 85: Train=6.468e-02 | Val=4.815e-01
# Epoch 86: Train=6.709e-02 | Val=6.012e-01
# Epoch 87: Train=9.563e-02 | Val=4.808e-01
# Epoch 88: Train=7.695e-02 | Val=5.128e-01
# Epoch 89: Train=6.573e-02 | Val=5.115e-01
# Epoch 90: Train=5.214e-02 | Val=5.680e-01
# Epoch 91: Train=5.742e-02 | Val=5.261e-01
# Epoch 92: Train=5.043e-02 | Val=5.534e-01
# Epoch 93: Train=4.731e-02 | Val=4.817e-01
# Epoch 94: Train=5.780e-02 | Val=4.673e-01
# Epoch 95: Train=4.739e-02 | Val=5.374e-01
# Epoch 96: Train=5.066e-02 | Val=4.785e-01
# Epoch 97: Train=5.393e-02 | Val=5.544e-01
# Epoch 98: Train=4.779e-02 | Val=5.407e-01
# Epoch 99: Train=5.196e-02 | Val=6.027e-01
# Epoch 100: Train=7.302e-02 | Val=4.801e-01
# CNN(
#   (conv): Sequential(
#     (0): Conv3d(2, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): GroupNorm(8, 32, eps=1e-05, affine=True)
#     (2): ReLU()
#     (3): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (5): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (6): ReLU()
#     (7): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (9): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (10): ReLU()
#     (11): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (pool): AdaptiveAvgPool3d(output_size=1)
#   (fc): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
evaluate_model(
        model, te_loader, test_ds,
        y_mean, y_std,
        vlin_baseline, rho_vlin
    )
