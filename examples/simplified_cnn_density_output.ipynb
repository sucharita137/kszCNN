# %%
import sys
import os
import numpy as np
import torch
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import train_test_split
from scipy.stats import pearsonr

# %%
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from kszcnn.simplified_cnn_density import *

# %%
np.random.seed(SEED)
torch.manual_seed(SEED)

# %%
#  1. Load grids
grid_train, grid_test = memmap_grid_slices(
    GRID_FILE, [TRAIN_REAL_IDX, TEST_REAL_IDX]
)

print("Grid shapes:", grid_train.shape, grid_test.shape)
# Out:
# Grid shapes: (128, 128, 128) (128, 128, 128)

# %%
# 2. Smooth density
delta_train = smooth_density_kspace(grid_train, SMOOTH_SCALE)
delta_test  = smooth_density_kspace(grid_test, SMOOTH_SCALE)

# %%
#  3. Normalize
mean = delta_train.mean()
std  = delta_train.std() + 1e-12

delta_train = (delta_train - mean) / std
delta_test  = (delta_test - mean) / std

# %%
# 4. Load halos
pos_tr, vel_tr, mass_tr = load_halos(TRAIN_HALO_FILE)
pos_te, vel_te, mass_te = load_halos(TEST_HALO_FILE)

print("Halos:", len(pos_tr), len(pos_te))
# Out:
# Halos: 20817 21205

# %%
#  5. Dataset 
rng = np.random.RandomState(SEED)
train_ds_full = HaloDataset(
    delta_train,
    pos_tr,
    vel_tr,
    mass_tr,
    mass_cut=MASS_CUT, max_n=MAX_HALOS,
    rng=rng
)

test_ds = HaloDataset(
    delta_test,
    pos_te,
    vel_te,
    mass_te,
    mass_cut=MASS_CUT, max_n=MAX_HALOS,
    rng=rng
)
# Out:
# Selected halos: 547
# Selected halos: 569

# %%
#  6. Linear baseline 
vlin_test = compute_vlin_from_density(
    grid_test,R_smooth=SMOOTH_SCALE
)

vlin_baseline = vlin_at_halos(vlin_test, test_ds.pos)

rho_vlin = pearsonr(test_ds.vz, vlin_baseline)[0]

print("Linear theory correlation:", rho_vlin)
# Out:
# Linear theory correlation: 0.8551195

# %%
#7. Train / validation
idxs = np.arange(len(train_ds_full))

tr_idx, val_idx = train_test_split(
    idxs,
    test_size=0.2,
    random_state=SEED
)

tr_ds  = Subset(train_ds_full, tr_idx)
val_ds = Subset(train_ds_full, val_idx)

# %%
#  8. Loaders
tr_loader = DataLoader(tr_ds, batch_size=BATCH, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH)
te_loader  = DataLoader(test_ds, batch_size=BATCH)

# %%
#  9. Normalize velocity
y_train = np.array([train_ds_full[i][1] for i in tr_idx])

y_mean = y_train.mean()
y_std  = y_train.std() + 1e-12

print("Velocity mean/std:", y_mean, y_std)
# Out:
# Velocity mean/std: -1.0862699 105.11467

# %%
model = CNN().to(DEVICE)

# %%
train_model(
        model, tr_loader, val_loader, y_mean, y_std
    )
# Out:
# Epoch 1: Train=3.169e-01 | Val=5.073e-01
# Epoch 2: Train=2.318e-01 | Val=4.370e-01
# Epoch 3: Train=2.088e-01 | Val=3.486e-01
# Epoch 4: Train=1.958e-01 | Val=3.740e-01
# Epoch 5: Train=1.934e-01 | Val=3.972e-01
# Epoch 6: Train=1.932e-01 | Val=3.208e-01
# Epoch 7: Train=1.904e-01 | Val=4.359e-01
# Epoch 8: Train=1.831e-01 | Val=3.078e-01
# Epoch 9: Train=1.784e-01 | Val=3.099e-01
# Epoch 10: Train=1.723e-01 | Val=2.951e-01
# Epoch 11: Train=1.798e-01 | Val=3.053e-01
# Epoch 12: Train=1.648e-01 | Val=3.167e-01
# Epoch 13: Train=1.640e-01 | Val=2.801e-01
# Epoch 14: Train=1.626e-01 | Val=3.890e-01
# Epoch 15: Train=1.779e-01 | Val=3.456e-01
# Epoch 16: Train=1.582e-01 | Val=3.830e-01
# Epoch 17: Train=1.615e-01 | Val=2.804e-01
# Epoch 18: Train=1.554e-01 | Val=2.737e-01
# Epoch 19: Train=1.458e-01 | Val=2.505e-01
# Epoch 20: Train=1.424e-01 | Val=2.430e-01
# Epoch 21: Train=1.511e-01 | Val=2.454e-01
# Epoch 22: Train=1.390e-01 | Val=2.793e-01
# Epoch 23: Train=1.561e-01 | Val=2.546e-01
# Epoch 24: Train=1.480e-01 | Val=2.519e-01
# Epoch 25: Train=1.445e-01 | Val=2.510e-01
# Epoch 26: Train=1.601e-01 | Val=2.393e-01
# Epoch 27: Train=1.383e-01 | Val=2.238e-01
# Epoch 28: Train=1.316e-01 | Val=2.574e-01
# Epoch 29: Train=1.541e-01 | Val=2.297e-01
# Epoch 30: Train=1.333e-01 | Val=2.490e-01
# Epoch 31: Train=1.363e-01 | Val=2.286e-01
# Epoch 32: Train=1.530e-01 | Val=4.274e-01
# Epoch 33: Train=1.548e-01 | Val=2.726e-01
# Epoch 34: Train=1.323e-01 | Val=2.220e-01
# Epoch 35: Train=1.224e-01 | Val=2.368e-01
# Epoch 36: Train=1.231e-01 | Val=2.364e-01
# Epoch 37: Train=1.313e-01 | Val=2.425e-01
# Epoch 38: Train=1.171e-01 | Val=2.562e-01
# Epoch 39: Train=1.181e-01 | Val=2.519e-01
# Epoch 40: Train=1.196e-01 | Val=2.045e-01
# Epoch 41: Train=1.215e-01 | Val=2.408e-01
# Epoch 42: Train=1.181e-01 | Val=2.122e-01
# Epoch 43: Train=1.103e-01 | Val=2.248e-01
# Epoch 44: Train=1.098e-01 | Val=2.902e-01
# Epoch 45: Train=1.262e-01 | Val=2.133e-01
# Epoch 46: Train=1.069e-01 | Val=2.761e-01
# Epoch 47: Train=1.119e-01 | Val=2.221e-01
# Epoch 48: Train=1.039e-01 | Val=2.056e-01
# Epoch 49: Train=1.068e-01 | Val=2.331e-01
# Epoch 50: Train=1.211e-01 | Val=2.069e-01
# Epoch 51: Train=1.206e-01 | Val=2.368e-01
# Epoch 52: Train=1.176e-01 | Val=2.299e-01
# Epoch 53: Train=1.007e-01 | Val=2.041e-01
# Epoch 54: Train=9.835e-02 | Val=2.059e-01
# Epoch 55: Train=1.157e-01 | Val=2.170e-01
# Epoch 56: Train=1.065e-01 | Val=2.943e-01
# Epoch 57: Train=9.711e-02 | Val=2.110e-01
# Epoch 58: Train=1.003e-01 | Val=2.372e-01
# Epoch 59: Train=1.145e-01 | Val=1.942e-01
# Epoch 60: Train=9.365e-02 | Val=2.078e-01
# Epoch 61: Train=9.562e-02 | Val=2.094e-01
# Epoch 62: Train=9.988e-02 | Val=2.478e-01
# Epoch 63: Train=9.099e-02 | Val=1.954e-01
# Epoch 64: Train=9.464e-02 | Val=1.940e-01
# Epoch 65: Train=9.764e-02 | Val=2.311e-01
# Epoch 66: Train=1.032e-01 | Val=1.883e-01
# Epoch 67: Train=1.070e-01 | Val=1.976e-01
# Epoch 68: Train=8.649e-02 | Val=2.064e-01
# Epoch 69: Train=9.196e-02 | Val=1.997e-01
# Epoch 70: Train=8.290e-02 | Val=1.826e-01
# Epoch 71: Train=9.159e-02 | Val=2.131e-01
# Epoch 72: Train=8.867e-02 | Val=1.775e-01
# Epoch 73: Train=8.449e-02 | Val=2.028e-01
# Epoch 74: Train=9.738e-02 | Val=2.260e-01
# Epoch 75: Train=9.471e-02 | Val=2.123e-01
# Epoch 76: Train=8.351e-02 | Val=3.194e-01
# Epoch 77: Train=1.113e-01 | Val=1.898e-01
# Epoch 78: Train=8.372e-02 | Val=2.164e-01
# Epoch 79: Train=8.347e-02 | Val=2.079e-01
# Epoch 80: Train=7.983e-02 | Val=2.061e-01
# Epoch 81: Train=7.996e-02 | Val=1.971e-01
# Epoch 82: Train=8.703e-02 | Val=1.971e-01
# Epoch 83: Train=8.497e-02 | Val=1.951e-01
# Epoch 84: Train=7.600e-02 | Val=1.978e-01
# Epoch 85: Train=6.941e-02 | Val=1.956e-01
# Epoch 86: Train=6.802e-02 | Val=1.976e-01
# Epoch 87: Train=6.791e-02 | Val=2.164e-01
# Epoch 88: Train=7.331e-02 | Val=2.118e-01
# Epoch 89: Train=7.574e-02 | Val=2.046e-01
# Epoch 90: Train=7.007e-02 | Val=1.993e-01
# Epoch 91: Train=7.794e-02 | Val=2.295e-01
# Epoch 92: Train=7.784e-02 | Val=2.263e-01
# Epoch 93: Train=6.760e-02 | Val=2.077e-01
# Epoch 94: Train=7.834e-02 | Val=2.094e-01
# Epoch 95: Train=8.540e-02 | Val=2.402e-01
# Epoch 96: Train=7.774e-02 | Val=2.043e-01
# Epoch 97: Train=6.696e-02 | Val=2.289e-01
# Epoch 98: Train=7.076e-02 | Val=2.216e-01
# Epoch 99: Train=6.894e-02 | Val=2.070e-01
# Epoch 100: Train=6.316e-02 | Val=2.210e-01
# CNN(
#   (conv): Sequential(
#     (0): Conv3d(1, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): GroupNorm(8, 32, eps=1e-05, affine=True)
#     (2): ReLU()
#     (3): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (5): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (6): ReLU()
#     (7): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (9): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (10): ReLU()
#     (11): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (pool): AdaptiveAvgPool3d(output_size=1)
#   (fc): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
evaluate_model(
        model, te_loader, test_ds,
        y_mean, y_std,
        vlin_baseline, rho_vlin
    )
# Out:
# ===== TEST RESULTS =====
# N = 569
# RMSE = 44.423
# RMS(true) = 96.798
# RMS(pred) = 90.821
