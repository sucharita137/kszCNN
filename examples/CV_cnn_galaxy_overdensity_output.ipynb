# %%
import sys
import os
import numpy as np
import torch
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import train_test_split
from scipy.stats import pearsonr

# %%
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from kszcnn.CV_cnn_galaxy_overdensity import *

# %%
print("TRAIN_HALO_FILE:", TRAIN_HALO_FILE)
print("TEST_HALO_FILE:",TEST_HALO_FILE)
# Out:
# TRAIN_HALO_FILE: /home/sucharita/kszCNN/data/groups_090_1P_0.hdf5
# TEST_HALO_FILE: /home/sucharita/kszCNN/data/groups_090_CV_5.hdf5

# %%
np.random.seed(SEED)
torch.manual_seed(SEED)

# %%
# load halos + subhalos
pos_tr, vel_tr, mass_tr, sub_pos_tr, sub_mstar_tr = \
    load_groups_and_subhalos(TRAIN_HALO_FILE)

# build galaxy overdensity field 
density_grid_tr = build_galaxy_density_grid(
    sub_pos_tr,
    sub_mstar_tr,
    Ngrid=128,
    mstar_cut=1e8
)

# smooth 
density_grid_tr = smooth_delta_field(density_grid_tr, SMOOTH_SCALE)
# Out:
# Selected galaxies: 923

# %%
pos_te, vel_te, mass_te, sub_pos_te, sub_mstar_te = \
    load_groups_and_subhalos(TEST_HALO_FILE)

density_grid_te = build_galaxy_density_grid(
    sub_pos_te,
    sub_mstar_te,
    Ngrid=128,
    mstar_cut=1e8
)

density_grid_te = smooth_delta_field(density_grid_te, SMOOTH_SCALE)
# Out:
# Selected galaxies: 904

# %%
#  5. Dataset 
rng = np.random.RandomState(SEED)
train_ds = HaloDataset(density_grid_tr, pos_tr, vel_tr, mass_tr, mass_cut=MASS_CUT, rng=rng)
test_ds  = HaloDataset(density_grid_te, pos_te, vel_te, mass_te, mass_cut=MASS_CUT, rng=rng)
# Out:
# Selected halos: 547
# Selected halos: 443

# %%
#  6. Linear baseline 
vlin_test = compute_vlin_from_delta(
    density_grid_te,   # now this is δg
    R_smooth=SMOOTH_SCALE
)

vlin_baseline = vlin_at_halos(vlin_test, test_ds.pos)

rho_vlin = pearsonr(test_ds.vz, vlin_baseline)[0]

print("Linear theory correlation (using δg):", rho_vlin)
# Out:
# Linear theory correlation (using δg): 0.72495174

# %%
#7. Train / validation
idxs = np.arange(len(train_ds))

tr_idx, val_idx = train_test_split(
    idxs,
    test_size=0.2,
    random_state=SEED
)

tr_ds  = Subset(train_ds, tr_idx)
val_ds = Subset(train_ds, val_idx)

# %%
#  8. Loaders
tr_loader = DataLoader(tr_ds, batch_size=BATCH, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH)
te_loader  = DataLoader(test_ds, batch_size=BATCH)

# %%
#  9. Normalize velocity
y_train = np.array([train_ds[i][1] for i in tr_idx])

y_mean = y_train.mean()
y_std  = y_train.std() + 1e-12

print("Velocity mean/std:", y_mean, y_std)
# Out:
# Velocity mean/std: -1.0862699 105.11467

# %%
model = CNN().to(DEVICE)

# %%
train_model(
        model, tr_loader, val_loader, y_mean, y_std
    )
# Out:
# Epoch 1: Train=4.761e-01 | Val=6.807e-01
# Epoch 2: Train=3.146e-01 | Val=8.122e-01
# Epoch 3: Train=3.093e-01 | Val=4.158e-01
# Epoch 4: Train=2.790e-01 | Val=4.503e-01
# Epoch 5: Train=2.571e-01 | Val=3.984e-01
# Epoch 6: Train=2.450e-01 | Val=3.601e-01
# Epoch 7: Train=2.529e-01 | Val=5.044e-01
# Epoch 8: Train=2.398e-01 | Val=3.330e-01
# Epoch 9: Train=2.435e-01 | Val=3.905e-01
# Epoch 10: Train=2.272e-01 | Val=3.177e-01
# Epoch 11: Train=2.515e-01 | Val=3.421e-01
# Epoch 12: Train=2.200e-01 | Val=3.574e-01
# Epoch 13: Train=2.171e-01 | Val=3.161e-01
# Epoch 14: Train=2.117e-01 | Val=3.463e-01
# Epoch 15: Train=2.129e-01 | Val=3.105e-01
# Epoch 16: Train=1.999e-01 | Val=4.563e-01
# Epoch 17: Train=2.074e-01 | Val=3.075e-01
# Epoch 18: Train=2.079e-01 | Val=2.920e-01
# Epoch 19: Train=1.933e-01 | Val=3.006e-01
# Epoch 20: Train=1.922e-01 | Val=2.657e-01
# Epoch 21: Train=1.832e-01 | Val=2.832e-01
# Epoch 22: Train=1.818e-01 | Val=4.177e-01
# Epoch 23: Train=2.543e-01 | Val=3.923e-01
# Epoch 24: Train=2.173e-01 | Val=3.004e-01
# Epoch 25: Train=1.972e-01 | Val=2.749e-01
# Epoch 26: Train=1.867e-01 | Val=2.689e-01
# Epoch 27: Train=1.901e-01 | Val=2.510e-01
# Epoch 28: Train=1.755e-01 | Val=2.764e-01
# Epoch 29: Train=1.853e-01 | Val=2.971e-01
# Epoch 30: Train=1.680e-01 | Val=2.601e-01
# Epoch 31: Train=1.669e-01 | Val=2.482e-01
# Epoch 32: Train=1.810e-01 | Val=2.833e-01
# Epoch 33: Train=1.736e-01 | Val=2.455e-01
# Epoch 34: Train=1.676e-01 | Val=3.151e-01
# Epoch 35: Train=1.535e-01 | Val=2.480e-01
# Epoch 36: Train=1.504e-01 | Val=2.472e-01
# Epoch 37: Train=1.570e-01 | Val=2.369e-01
# Epoch 38: Train=1.445e-01 | Val=2.607e-01
# Epoch 39: Train=1.468e-01 | Val=2.834e-01
# Epoch 40: Train=1.521e-01 | Val=2.261e-01
# Epoch 41: Train=1.553e-01 | Val=2.285e-01
# Epoch 42: Train=1.574e-01 | Val=2.539e-01
# Epoch 43: Train=1.387e-01 | Val=2.524e-01
# Epoch 44: Train=1.417e-01 | Val=2.632e-01
# Epoch 45: Train=1.496e-01 | Val=2.381e-01
# Epoch 46: Train=1.398e-01 | Val=2.732e-01
# Epoch 47: Train=1.450e-01 | Val=2.522e-01
# Epoch 48: Train=1.346e-01 | Val=2.375e-01
# Epoch 49: Train=1.288e-01 | Val=2.550e-01
# Epoch 50: Train=1.394e-01 | Val=2.180e-01
# Epoch 51: Train=1.388e-01 | Val=2.410e-01
# Epoch 52: Train=1.408e-01 | Val=2.930e-01
# Epoch 53: Train=1.632e-01 | Val=2.490e-01
# Epoch 54: Train=1.291e-01 | Val=2.359e-01
# Epoch 55: Train=1.453e-01 | Val=2.093e-01
# Epoch 56: Train=1.287e-01 | Val=2.217e-01
# Epoch 57: Train=1.316e-01 | Val=2.090e-01
# Epoch 58: Train=1.199e-01 | Val=2.645e-01
# Epoch 59: Train=1.409e-01 | Val=2.202e-01
# Epoch 60: Train=1.170e-01 | Val=2.523e-01
# Epoch 61: Train=1.169e-01 | Val=2.479e-01
# Epoch 62: Train=1.312e-01 | Val=2.141e-01
# Epoch 63: Train=1.075e-01 | Val=2.091e-01
# Epoch 64: Train=1.068e-01 | Val=2.037e-01
# Epoch 65: Train=1.199e-01 | Val=2.081e-01
# Epoch 66: Train=1.083e-01 | Val=2.481e-01
# Epoch 67: Train=1.713e-01 | Val=2.436e-01
# Epoch 68: Train=1.180e-01 | Val=2.622e-01
# Epoch 69: Train=1.126e-01 | Val=2.503e-01
# Epoch 70: Train=1.103e-01 | Val=2.130e-01
# Epoch 71: Train=1.196e-01 | Val=2.008e-01
# Epoch 72: Train=1.021e-01 | Val=2.108e-01
# Epoch 73: Train=9.710e-02 | Val=2.143e-01
# Epoch 74: Train=1.203e-01 | Val=2.580e-01
# Epoch 75: Train=1.138e-01 | Val=2.096e-01
# Epoch 76: Train=9.243e-02 | Val=2.785e-01
# Epoch 77: Train=1.357e-01 | Val=1.887e-01
# Epoch 78: Train=9.759e-02 | Val=2.035e-01
# Epoch 79: Train=1.005e-01 | Val=2.088e-01
# Epoch 80: Train=9.482e-02 | Val=2.105e-01
# Epoch 81: Train=9.127e-02 | Val=1.916e-01
# Epoch 82: Train=9.452e-02 | Val=2.064e-01
# Epoch 83: Train=9.776e-02 | Val=2.273e-01
# Epoch 84: Train=8.696e-02 | Val=2.262e-01
# Epoch 85: Train=7.897e-02 | Val=2.179e-01
# Epoch 86: Train=7.765e-02 | Val=1.995e-01
# Epoch 87: Train=7.312e-02 | Val=2.076e-01
# Epoch 88: Train=8.092e-02 | Val=2.113e-01
# Epoch 89: Train=8.698e-02 | Val=2.542e-01
# Epoch 90: Train=8.716e-02 | Val=2.595e-01
# Epoch 91: Train=1.011e-01 | Val=2.123e-01
# Epoch 92: Train=9.584e-02 | Val=2.361e-01
# Epoch 93: Train=7.879e-02 | Val=2.416e-01
# Epoch 94: Train=8.414e-02 | Val=2.351e-01
# Epoch 95: Train=8.027e-02 | Val=2.363e-01
# Epoch 96: Train=8.473e-02 | Val=2.226e-01
# Epoch 97: Train=8.623e-02 | Val=2.156e-01
# Epoch 98: Train=8.068e-02 | Val=2.223e-01
# Epoch 99: Train=7.202e-02 | Val=2.246e-01
# Epoch 100: Train=7.395e-02 | Val=2.481e-01
# CNN(
#   (conv): Sequential(
#     (0): Conv3d(1, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): GroupNorm(8, 32, eps=1e-05, affine=True)
#     (2): ReLU()
#     (3): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (5): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (6): ReLU()
#     (7): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (9): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (10): ReLU()
#     (11): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (pool): AdaptiveAvgPool3d(output_size=1)
#   (fc): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
evaluate_model(
        model, te_loader, test_ds,
        y_mean, y_std,
        vlin_baseline, rho_vlin
    )
# Out:
# ===== TEST RESULTS =====
# RMSE = 76.66
# corr.coef r = 0.72
# m = 0.62
# b = 11.87
# metric_val = 0.39
