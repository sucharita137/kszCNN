# %%
import sys
import os
import numpy as np
import torch
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import train_test_split
from scipy.stats import pearsonr

# %%
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from kszcnn.simplified_cnn_err_pos import *

# %%
np.random.seed(SEED)
torch.manual_seed(SEED)

# %%
#  1. Load grids
grid_train, grid_test = memmap_grid_slices(
    GRID_FILE, [TRAIN_REAL_IDX, TEST_REAL_IDX]
)

print("Grid shapes:", grid_train.shape, grid_test.shape)
# Out:
# Grid shapes: (128, 128, 128) (128, 128, 128)

# %%
# 2. Smooth density
delta_train = smooth_density_kspace(grid_train, SMOOTH_SCALE)
delta_test  = smooth_density_kspace(grid_test, SMOOTH_SCALE)

# %%
#  3. Normalize
mean = delta_train.mean()
std  = delta_train.std() + 1e-12

delta_train = (delta_train - mean) / std
delta_test  = (delta_test - mean) / std

# %%
# 4. Load halos
pos_tr, vel_tr, mass_tr = load_halos(TRAIN_HALO_FILE)
pos_te, vel_te, mass_te = load_halos(TEST_HALO_FILE)

pos_tr = redshift_err(pos_tr, sigma_z=1e-4)
pos_te = redshift_err(pos_te, sigma_z=1e-4)


print("Halos:", len(pos_tr), len(pos_te))
# Out:
# Halos: 20817 21205

# %%
#  5. Dataset 
rng = np.random.RandomState(SEED)
train_ds_full = HaloDataset(
    delta_train,
    pos_tr,
    vel_tr,
    mass_tr,
    mass_cut=MASS_CUT, max_n=MAX_HALOS,
    rng=rng
)

test_ds = HaloDataset(
    delta_test,
    pos_te,
    vel_te,
    mass_te,
    mass_cut=MASS_CUT, max_n=MAX_HALOS,
    rng=rng
)
# Out:
# Selected halos: 547
# Selected halos: 569

# %%
#  6. Linear baseline 
vlin_test = compute_vlin_from_density(
    grid_test,R_smooth=SMOOTH_SCALE
)

vlin_baseline = vlin_at_halos(vlin_test, test_ds.pos)

rho_vlin = pearsonr(test_ds.vz, vlin_baseline)[0]

print("Linear theory correlation:", rho_vlin)
# Out:
# Linear theory correlation: 0.8239114

# %%
#7. Train / validation
idxs = np.arange(len(train_ds_full))

tr_idx, val_idx = train_test_split(
    idxs,
    test_size=0.2,
    random_state=SEED
)

tr_ds  = Subset(train_ds_full, tr_idx)
val_ds = Subset(train_ds_full, val_idx)

# %%
#  8. Loaders
tr_loader = DataLoader(tr_ds, batch_size=BATCH, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH)
te_loader  = DataLoader(test_ds, batch_size=BATCH)

# %%
#  9. Normalize velocity
y_train = np.array([train_ds_full[i][1] for i in tr_idx])

y_mean = y_train.mean()
y_std  = y_train.std() + 1e-12

print("Velocity mean/std:", y_mean, y_std)
# Out:
# Velocity mean/std: -1.0862699 105.11467

# %%
model = CNN().to(DEVICE)

# %%
train_model(
        model, tr_loader, val_loader, y_mean, y_std
    )
# Out:
# Epoch 1: Train=3.740e-01 | Val=8.136e-01
# Epoch 2: Train=3.541e-01 | Val=8.324e-01
# Epoch 3: Train=3.036e-01 | Val=6.923e-01
# Epoch 4: Train=2.596e-01 | Val=7.327e-01
# Epoch 5: Train=2.329e-01 | Val=6.402e-01
# Epoch 6: Train=2.329e-01 | Val=5.854e-01
# Epoch 7: Train=2.175e-01 | Val=6.546e-01
# Epoch 8: Train=2.196e-01 | Val=5.594e-01
# Epoch 9: Train=2.211e-01 | Val=5.541e-01
# Epoch 10: Train=2.065e-01 | Val=4.907e-01
# Epoch 11: Train=2.137e-01 | Val=6.091e-01
# Epoch 12: Train=2.102e-01 | Val=5.538e-01
# Epoch 13: Train=1.908e-01 | Val=4.716e-01
# Epoch 14: Train=1.931e-01 | Val=5.420e-01
# Epoch 15: Train=1.765e-01 | Val=4.474e-01
# Epoch 16: Train=1.936e-01 | Val=4.542e-01
# Epoch 17: Train=1.851e-01 | Val=4.512e-01
# Epoch 18: Train=1.858e-01 | Val=5.410e-01
# Epoch 19: Train=1.745e-01 | Val=5.681e-01
# Epoch 20: Train=1.794e-01 | Val=4.310e-01
# Epoch 21: Train=1.689e-01 | Val=4.997e-01
# Epoch 22: Train=1.843e-01 | Val=4.007e-01
# Epoch 23: Train=1.767e-01 | Val=3.902e-01
# Epoch 24: Train=1.553e-01 | Val=4.151e-01
# Epoch 25: Train=1.524e-01 | Val=3.851e-01
# Epoch 26: Train=1.578e-01 | Val=4.014e-01
# Epoch 27: Train=1.597e-01 | Val=3.953e-01
# Epoch 28: Train=1.592e-01 | Val=3.984e-01
# Epoch 29: Train=1.575e-01 | Val=3.682e-01
# Epoch 30: Train=1.645e-01 | Val=4.203e-01
# Epoch 31: Train=1.592e-01 | Val=4.591e-01
# Epoch 32: Train=1.488e-01 | Val=3.716e-01
# Epoch 33: Train=1.450e-01 | Val=3.846e-01
# Epoch 34: Train=1.686e-01 | Val=3.721e-01
# Epoch 35: Train=1.500e-01 | Val=5.739e-01
# Epoch 36: Train=1.553e-01 | Val=3.460e-01
# Epoch 37: Train=1.511e-01 | Val=4.084e-01
# Epoch 38: Train=1.458e-01 | Val=4.285e-01
# Epoch 39: Train=1.423e-01 | Val=4.165e-01
# Epoch 40: Train=1.373e-01 | Val=4.069e-01
# Epoch 41: Train=1.427e-01 | Val=3.759e-01
# Epoch 42: Train=1.355e-01 | Val=4.715e-01
# Epoch 43: Train=1.307e-01 | Val=4.573e-01
# Epoch 44: Train=1.335e-01 | Val=3.722e-01
# Epoch 45: Train=1.322e-01 | Val=3.512e-01
# Epoch 46: Train=1.338e-01 | Val=3.506e-01
# Epoch 47: Train=1.465e-01 | Val=5.778e-01
# Epoch 48: Train=1.276e-01 | Val=3.980e-01
# Epoch 49: Train=1.283e-01 | Val=6.932e-01
# Epoch 50: Train=1.359e-01 | Val=3.785e-01
# Epoch 51: Train=1.312e-01 | Val=3.510e-01
# Epoch 52: Train=1.331e-01 | Val=3.520e-01
# Epoch 53: Train=1.121e-01 | Val=3.670e-01
# Epoch 54: Train=1.346e-01 | Val=3.856e-01
# Epoch 55: Train=1.226e-01 | Val=3.780e-01
# Epoch 56: Train=1.356e-01 | Val=3.771e-01
# Epoch 57: Train=1.113e-01 | Val=4.481e-01
# Epoch 58: Train=1.140e-01 | Val=3.847e-01
# Epoch 59: Train=1.257e-01 | Val=4.025e-01
# Epoch 60: Train=1.436e-01 | Val=5.170e-01
# Epoch 61: Train=1.260e-01 | Val=5.283e-01
# Epoch 62: Train=1.272e-01 | Val=3.440e-01
# Epoch 63: Train=1.135e-01 | Val=4.170e-01
# Epoch 64: Train=1.037e-01 | Val=4.111e-01
# Epoch 65: Train=1.143e-01 | Val=4.142e-01
# Epoch 66: Train=1.173e-01 | Val=4.236e-01
# Epoch 67: Train=1.029e-01 | Val=3.862e-01
# Epoch 68: Train=1.028e-01 | Val=4.897e-01
# Epoch 69: Train=1.077e-01 | Val=4.715e-01
# Epoch 70: Train=1.275e-01 | Val=3.955e-01
# Epoch 71: Train=1.022e-01 | Val=3.845e-01
# Epoch 72: Train=9.062e-02 | Val=4.417e-01
# Epoch 73: Train=9.204e-02 | Val=4.110e-01
# Epoch 74: Train=9.214e-02 | Val=3.839e-01
# Epoch 75: Train=9.398e-02 | Val=3.747e-01
# Epoch 76: Train=8.811e-02 | Val=3.897e-01
# Epoch 77: Train=1.210e-01 | Val=4.009e-01
# Epoch 78: Train=9.459e-02 | Val=4.232e-01
# Epoch 79: Train=1.098e-01 | Val=3.805e-01
# Epoch 80: Train=9.236e-02 | Val=4.479e-01
# Epoch 81: Train=9.358e-02 | Val=3.885e-01
# Epoch 82: Train=9.877e-02 | Val=4.188e-01
# Epoch 83: Train=1.030e-01 | Val=3.855e-01
# Epoch 84: Train=1.042e-01 | Val=4.340e-01
# Epoch 85: Train=1.893e-01 | Val=4.576e-01
# Epoch 86: Train=1.317e-01 | Val=3.636e-01
# Epoch 87: Train=1.055e-01 | Val=3.443e-01
# Epoch 88: Train=9.990e-02 | Val=4.326e-01
# Epoch 89: Train=9.102e-02 | Val=4.484e-01
# Epoch 90: Train=8.957e-02 | Val=3.851e-01
# Epoch 91: Train=1.063e-01 | Val=5.412e-01
# Epoch 92: Train=1.085e-01 | Val=3.992e-01
# Epoch 93: Train=9.209e-02 | Val=3.630e-01
# Epoch 94: Train=9.154e-02 | Val=3.220e-01
# Epoch 95: Train=8.648e-02 | Val=3.821e-01
# Epoch 96: Train=8.068e-02 | Val=4.238e-01
# Epoch 97: Train=9.184e-02 | Val=4.800e-01
# Epoch 98: Train=1.000e-01 | Val=3.801e-01
# Epoch 99: Train=9.626e-02 | Val=4.111e-01
# Epoch 100: Train=8.203e-02 | Val=4.254e-01
# CNN(
#   (conv): Sequential(
#     (0): Conv3d(3, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): GroupNorm(8, 32, eps=1e-05, affine=True)
#     (2): ReLU()
#     (3): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (5): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (6): ReLU()
#     (7): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (9): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (10): ReLU()
#     (11): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (pool): AdaptiveAvgPool3d(output_size=1)
#   (fc): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
evaluate_model(
        model, te_loader, test_ds,
        y_mean, y_std,
        vlin_baseline, rho_vlin
    )
# Out:
# p68 = 45.648476
# p95 = 118.50042
# p99 = 230.601
# ===== TEST RESULTS =====
# N = 569
# RMSE = 62.222
# RMS(true) = 96.798
# RMS(pred) = 83.859
