# %%
import sys
import os
import numpy as np
import torch
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import train_test_split
from scipy.stats import pearsonr

# %%
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from kszcnn.simplified_cnn_density_pos import *

# %%
np.random.seed(SEED)
torch.manual_seed(SEED)

# %%
#  1. Load grids
grid_train, grid_test = memmap_grid_slices(
    GRID_FILE, [TRAIN_REAL_IDX, TEST_REAL_IDX]
)

print("Grid shapes:", grid_train.shape, grid_test.shape)
# Out:
# Grid shapes: (128, 128, 128) (128, 128, 128)

# %%
# 2. Smooth density
delta_train = smooth_density_kspace(grid_train, SMOOTH_SCALE)
delta_test  = smooth_density_kspace(grid_test, SMOOTH_SCALE)

# %%
#  3. Normalize
mean = delta_train.mean()
std  = delta_train.std() + 1e-12

delta_train = (delta_train - mean) / std
delta_test  = (delta_test - mean) / std

# %%
# 4. Load halos
pos_tr, vel_tr, mass_tr = load_halos(TRAIN_HALO_FILE)
pos_te, vel_te, mass_te = load_halos(TEST_HALO_FILE)

print("Halos:", len(pos_tr), len(pos_te))
# Out:
# Halos: 20817 21205

# %%
#  5. Dataset 
rng = np.random.RandomState(SEED)
train_ds_full = HaloDataset(
    delta_train,
    pos_tr,
    vel_tr,
    mass_tr,
    mass_cut=MASS_CUT, max_n=MAX_HALOS,
    rng=rng
)

test_ds = HaloDataset(
    delta_test,
    pos_te,
    vel_te,
    mass_te,
    mass_cut=MASS_CUT, max_n=MAX_HALOS,
    rng=rng
)
# Out:
# Selected halos: 547
# Selected halos: 569

# %%
#  6. Linear baseline 
vlin_test = compute_vlin_from_density(
    grid_test,R_smooth=SMOOTH_SCALE
)

vlin_baseline = vlin_at_halos(vlin_test, test_ds.pos)

rho_vlin = pearsonr(test_ds.vz, vlin_baseline)[0]

print("Linear theory correlation:", rho_vlin)
# Out:
# Linear theory correlation: 0.8551195

# %%
#7. Train / validation
idxs = np.arange(len(train_ds_full))

tr_idx, val_idx = train_test_split(
    idxs,
    test_size=0.2,
    random_state=SEED
)

tr_ds  = Subset(train_ds_full, tr_idx)
val_ds = Subset(train_ds_full, val_idx)

# %%
#  8. Loaders
tr_loader = DataLoader(tr_ds, batch_size=BATCH, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH)
te_loader  = DataLoader(test_ds, batch_size=BATCH)

# %%
#  9. Normalize velocity
y_train = np.array([train_ds_full[i][1] for i in tr_idx])

y_mean = y_train.mean()
y_std  = y_train.std() + 1e-12

print("Velocity mean/std:", y_mean, y_std)
# Out:
# Velocity mean/std: -1.0862699 105.11467

# %%
model = CNN().to(DEVICE)

# %%
train_model(
        model, tr_loader, val_loader, y_mean, y_std
    )
# Out:
# Epoch 1: Train=2.645e-01 | Val=5.440e-01
# Epoch 2: Train=1.763e-01 | Val=3.298e-01
# Epoch 3: Train=1.974e-01 | Val=3.166e-01
# Epoch 4: Train=1.540e-01 | Val=3.172e-01
# Epoch 5: Train=1.521e-01 | Val=2.797e-01
# Epoch 6: Train=1.460e-01 | Val=3.461e-01
# Epoch 7: Train=1.872e-01 | Val=4.249e-01
# Epoch 8: Train=1.567e-01 | Val=2.568e-01
# Epoch 9: Train=1.398e-01 | Val=2.458e-01
# Epoch 10: Train=1.351e-01 | Val=2.377e-01
# Epoch 11: Train=1.233e-01 | Val=2.419e-01
# Epoch 12: Train=1.199e-01 | Val=2.225e-01
# Epoch 13: Train=1.264e-01 | Val=2.397e-01
# Epoch 14: Train=1.274e-01 | Val=2.209e-01
# Epoch 15: Train=1.296e-01 | Val=2.032e-01
# Epoch 16: Train=1.180e-01 | Val=2.219e-01
# Epoch 17: Train=1.145e-01 | Val=1.948e-01
# Epoch 18: Train=1.119e-01 | Val=2.513e-01
# Epoch 19: Train=1.043e-01 | Val=2.282e-01
# Epoch 20: Train=1.307e-01 | Val=2.788e-01
# Epoch 21: Train=1.168e-01 | Val=2.066e-01
# Epoch 22: Train=9.908e-02 | Val=1.936e-01
# Epoch 23: Train=1.069e-01 | Val=2.939e-01
# Epoch 24: Train=1.166e-01 | Val=2.389e-01
# Epoch 25: Train=1.057e-01 | Val=2.091e-01
# Epoch 26: Train=9.696e-02 | Val=2.015e-01
# Epoch 27: Train=9.576e-02 | Val=2.055e-01
# Epoch 28: Train=9.738e-02 | Val=2.415e-01
# Epoch 29: Train=1.238e-01 | Val=1.703e-01
# Epoch 30: Train=9.649e-02 | Val=2.350e-01
# Epoch 31: Train=9.678e-02 | Val=1.877e-01
# Epoch 32: Train=1.096e-01 | Val=1.993e-01
# Epoch 33: Train=9.943e-02 | Val=2.100e-01
# Epoch 34: Train=8.979e-02 | Val=2.039e-01
# Epoch 35: Train=9.544e-02 | Val=2.965e-01
# Epoch 36: Train=1.269e-01 | Val=2.352e-01
# Epoch 37: Train=9.366e-02 | Val=2.007e-01
# Epoch 38: Train=9.708e-02 | Val=1.804e-01
# Epoch 39: Train=8.681e-02 | Val=1.878e-01
# Epoch 40: Train=8.445e-02 | Val=1.861e-01
# Epoch 41: Train=7.921e-02 | Val=2.152e-01
# Epoch 42: Train=8.821e-02 | Val=2.944e-01
# Epoch 43: Train=1.025e-01 | Val=2.034e-01
# Epoch 44: Train=9.080e-02 | Val=1.752e-01
# Epoch 45: Train=7.681e-02 | Val=1.920e-01
# Epoch 46: Train=7.748e-02 | Val=2.050e-01
# Epoch 47: Train=8.020e-02 | Val=1.861e-01
# Epoch 48: Train=8.047e-02 | Val=1.953e-01
# Epoch 49: Train=8.701e-02 | Val=1.849e-01
# Epoch 50: Train=8.015e-02 | Val=2.097e-01
# Epoch 51: Train=7.243e-02 | Val=2.177e-01
# Epoch 52: Train=7.636e-02 | Val=2.664e-01
# Epoch 53: Train=8.107e-02 | Val=2.056e-01
# Epoch 54: Train=8.485e-02 | Val=1.864e-01
# Epoch 55: Train=7.453e-02 | Val=2.092e-01
# Epoch 56: Train=7.242e-02 | Val=2.036e-01
# Epoch 57: Train=7.014e-02 | Val=2.181e-01
# Epoch 58: Train=7.843e-02 | Val=2.266e-01
# Epoch 59: Train=7.335e-02 | Val=2.061e-01
# Epoch 60: Train=7.068e-02 | Val=1.839e-01
# Epoch 61: Train=6.418e-02 | Val=1.961e-01
# Epoch 62: Train=6.547e-02 | Val=2.213e-01
# Epoch 63: Train=6.576e-02 | Val=1.998e-01
# Epoch 64: Train=7.195e-02 | Val=1.994e-01
# Epoch 65: Train=6.078e-02 | Val=2.146e-01
# Epoch 66: Train=6.771e-02 | Val=2.012e-01
# Epoch 67: Train=6.525e-02 | Val=2.098e-01
# Epoch 68: Train=6.545e-02 | Val=2.593e-01
# Epoch 69: Train=6.047e-02 | Val=2.118e-01
# Epoch 70: Train=7.025e-02 | Val=3.692e-01
# Epoch 71: Train=7.145e-02 | Val=2.057e-01
# Epoch 72: Train=5.893e-02 | Val=2.105e-01
# Epoch 73: Train=5.736e-02 | Val=2.267e-01
# Epoch 74: Train=6.995e-02 | Val=2.002e-01
# Epoch 75: Train=6.417e-02 | Val=2.026e-01
# Epoch 76: Train=6.051e-02 | Val=2.733e-01
# Epoch 77: Train=6.670e-02 | Val=2.084e-01
# Epoch 78: Train=5.941e-02 | Val=2.184e-01
# Epoch 79: Train=5.721e-02 | Val=2.150e-01
# Epoch 80: Train=5.107e-02 | Val=2.165e-01
# Epoch 81: Train=5.593e-02 | Val=2.005e-01
# Epoch 82: Train=6.242e-02 | Val=2.305e-01
# Epoch 83: Train=5.626e-02 | Val=2.481e-01
# Epoch 84: Train=6.552e-02 | Val=2.388e-01
# Epoch 85: Train=5.578e-02 | Val=2.332e-01
# Epoch 86: Train=5.499e-02 | Val=2.334e-01
# Epoch 87: Train=4.985e-02 | Val=2.251e-01
# Epoch 88: Train=5.678e-02 | Val=2.080e-01
# Epoch 89: Train=4.815e-02 | Val=2.199e-01
# Epoch 90: Train=5.143e-02 | Val=2.144e-01
# Epoch 91: Train=4.922e-02 | Val=2.144e-01
# Epoch 92: Train=4.891e-02 | Val=2.468e-01
# Epoch 93: Train=5.280e-02 | Val=2.701e-01
# Epoch 94: Train=5.355e-02 | Val=2.398e-01
# Epoch 95: Train=5.947e-02 | Val=2.448e-01
# Epoch 96: Train=4.926e-02 | Val=2.152e-01
# Epoch 97: Train=4.688e-02 | Val=2.341e-01
# Epoch 98: Train=4.500e-02 | Val=3.483e-01
# Epoch 99: Train=5.189e-02 | Val=2.559e-01
# Epoch 100: Train=5.040e-02 | Val=2.391e-01
# CNN(
#   (conv): Sequential(
#     (0): Conv3d(4, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): GroupNorm(8, 32, eps=1e-05, affine=True)
#     (2): ReLU()
#     (3): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (5): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (6): ReLU()
#     (7): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (9): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (10): ReLU()
#     (11): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (pool): AdaptiveAvgPool3d(output_size=1)
#   (fc): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
evaluate_model(
        model, te_loader, test_ds,
        y_mean, y_std,
        vlin_baseline, rho_vlin
    )
# Out:
# ===== TEST RESULTS =====
# N = 569
# RMSE = 47.584
# RMS(true) = 96.798
# RMS(pred) = 92.089
