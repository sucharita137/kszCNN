# %%
import sys
import os
import numpy as np
import torch
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import train_test_split
from scipy.stats import pearsonr

# %%
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from kszcnn.same_real_cnn_density_N_sub import *

# %%
print("SET:", set_name)
print("GRID_FILE:", GRID_FILE)
print("HALO_FILE:", HALO_FILE)
print("REAL_IDX:", REAL_IDX)
# Out:
# SET: 1P_0
# GRID_FILE: /home/sucharita/kszCNN/data/Grids_Mcdm_IllustrisTNG_1P_128_z=0.0.npy
# HALO_FILE: /home/sucharita/kszCNN/data/groups_090_1P_0.hdf5
# REAL_IDX: 0

# %%
np.random.seed(SEED)
torch.manual_seed(SEED)

# %%
#  1. Load grids
grid = memmap_grid_slices(GRID_FILE, [REAL_IDX])[0]

print("Grid shapes:", grid.shape)
# Out:
# Grid shapes: (128, 128, 128)

# %%
# 2. Smooth density
delta = smooth_density_kspace(grid, SMOOTH_SCALE)

# %%
#  3. Normalize
mean = delta.mean()
std  = delta.std() + 1e-12

delta = (delta - mean) / std

# %%
# 4. Load halos
pos, vel, mass = load_halos(HALO_FILE)
feature = load_feature_file(HALO_FILE, feature_type="nsubs")

# %%
rng1 = np.random.RandomState(SEED)
rng2 = np.random.RandomState(SEED + 1)

# %%
full_ds_clean = HaloDataset(
    delta, pos, vel,
    mass,
    feature,
    feature_type="nsubs",
    mass_cut=MASS_CUT,
    rng=rng1
)
# Out:
# Selected halos: 547

# %%
idxs = np.arange(len(full_ds_clean))

train_idx, test_idx = train_test_split(
    idxs, test_size=0.2, random_state=SEED
)

train_idx, val_idx = train_test_split(
    train_idx, test_size=0.2, random_state=SEED)

# %%
pos_all = pos.copy()

pos_all[test_idx] = redshift_err(
    pos_all[test_idx], sigma_z=1e-4)

# %%
full_ds = HaloDataset(
    delta, pos_all, vel, mass,
    feature,
    feature_type="nsubs", 
    mass_cut=MASS_CUT,
    rng=rng2
)
# Out:
# Selected halos: 547

# %%
train_ds = Subset(full_ds, train_idx)
val_ds   = Subset(full_ds, val_idx)
test_ds  = Subset(full_ds, test_idx)

# %%
tr_loader = DataLoader(train_ds, batch_size=BATCH, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH)
te_loader  = DataLoader(test_ds, batch_size=BATCH)

# %%
#  9. Normalize velocity
y_train = np.array([full_ds[i][1] for i in train_idx])

y_mean = y_train.mean()
y_std  = y_train.std() + 1e-12

print("Velocity mean/std:", y_mean, y_std)
# Out:
# Velocity mean/std: 0.36430642 107.621216

# %%
#  6. Linear baseline 
vlin_grid = compute_vlin_from_density(
    grid, R_smooth=SMOOTH_SCALE
    )

test_pos = np.array([full_ds.pos[i] for i in test_idx])
true_vz  = full_ds.vz[test_idx]
vlin_baseline = vlin_at_halos(vlin_grid, test_pos)
rho_vlin = np.corrcoef(true_vz, vlin_baseline)[0,1]


print("Linear theory correlation:", rho_vlin)
# Out:
# Linear theory correlation: 0.8811998544715238

# %%
model = CNN(in_ch=2).to(DEVICE)

# %%
train_model(
        model, tr_loader, val_loader, y_mean, y_std
    )
# Out:
# Epoch 1: Train=4.888e-01 | Val=5.918e-01
# Epoch 2: Train=3.805e-01 | Val=5.244e-01
# Epoch 3: Train=3.124e-01 | Val=3.381e-01
# Epoch 4: Train=2.701e-01 | Val=3.737e-01
# Epoch 5: Train=2.505e-01 | Val=3.186e-01
# Epoch 6: Train=2.575e-01 | Val=3.426e-01
# Epoch 7: Train=2.327e-01 | Val=3.316e-01
# Epoch 8: Train=2.270e-01 | Val=3.319e-01
# Epoch 9: Train=2.265e-01 | Val=3.538e-01
# Epoch 10: Train=2.394e-01 | Val=3.305e-01
# Epoch 11: Train=2.161e-01 | Val=3.356e-01
# Epoch 12: Train=2.266e-01 | Val=3.502e-01
# Epoch 13: Train=2.158e-01 | Val=3.471e-01
# Epoch 14: Train=2.039e-01 | Val=3.336e-01
# Epoch 15: Train=2.021e-01 | Val=3.250e-01
# Epoch 16: Train=2.052e-01 | Val=3.131e-01
# Epoch 17: Train=2.130e-01 | Val=3.133e-01
# Epoch 18: Train=1.913e-01 | Val=3.416e-01
# Epoch 19: Train=1.920e-01 | Val=3.733e-01
# Epoch 20: Train=2.063e-01 | Val=3.570e-01
# Epoch 21: Train=1.937e-01 | Val=3.565e-01
# Epoch 22: Train=1.911e-01 | Val=3.863e-01
# Epoch 23: Train=1.846e-01 | Val=3.260e-01
# Epoch 24: Train=1.867e-01 | Val=3.866e-01
# Epoch 25: Train=1.910e-01 | Val=3.124e-01
# Epoch 26: Train=1.816e-01 | Val=3.009e-01
# Epoch 27: Train=1.619e-01 | Val=3.143e-01
# Epoch 28: Train=1.626e-01 | Val=3.862e-01
# Epoch 29: Train=1.791e-01 | Val=3.135e-01
# Epoch 30: Train=1.583e-01 | Val=3.298e-01
# Epoch 31: Train=1.754e-01 | Val=3.155e-01
# Epoch 32: Train=1.648e-01 | Val=3.728e-01
# Epoch 33: Train=1.646e-01 | Val=3.377e-01
# Epoch 34: Train=1.566e-01 | Val=3.206e-01
# Epoch 35: Train=1.458e-01 | Val=3.473e-01
# Epoch 36: Train=1.420e-01 | Val=4.295e-01
# Epoch 37: Train=1.604e-01 | Val=3.956e-01
# Epoch 38: Train=1.442e-01 | Val=3.248e-01
# Epoch 39: Train=1.405e-01 | Val=3.701e-01
# Epoch 40: Train=1.405e-01 | Val=3.938e-01
# Epoch 41: Train=1.252e-01 | Val=3.858e-01
# Epoch 42: Train=1.361e-01 | Val=3.308e-01
# Epoch 43: Train=1.278e-01 | Val=2.899e-01
# Epoch 44: Train=1.287e-01 | Val=2.996e-01
# Epoch 45: Train=1.267e-01 | Val=3.189e-01
# Epoch 46: Train=1.334e-01 | Val=2.927e-01
# Epoch 47: Train=1.185e-01 | Val=3.824e-01
# Epoch 48: Train=1.153e-01 | Val=3.125e-01
# Epoch 49: Train=1.117e-01 | Val=3.321e-01
# Epoch 50: Train=1.292e-01 | Val=3.422e-01
# Epoch 51: Train=1.180e-01 | Val=3.429e-01
# Epoch 52: Train=1.356e-01 | Val=3.017e-01
# Epoch 53: Train=1.405e-01 | Val=3.124e-01
# Epoch 54: Train=1.359e-01 | Val=3.441e-01
# Epoch 55: Train=1.328e-01 | Val=3.285e-01
# Epoch 56: Train=1.375e-01 | Val=3.085e-01
# Epoch 57: Train=1.136e-01 | Val=2.987e-01
# Epoch 58: Train=1.007e-01 | Val=3.538e-01
# Epoch 59: Train=1.036e-01 | Val=4.013e-01
# Epoch 60: Train=1.019e-01 | Val=3.257e-01
# Epoch 61: Train=9.084e-02 | Val=2.979e-01
# Epoch 62: Train=9.792e-02 | Val=2.966e-01
# Epoch 63: Train=8.504e-02 | Val=3.149e-01
# Epoch 64: Train=8.673e-02 | Val=3.797e-01
# Epoch 65: Train=8.996e-02 | Val=2.759e-01
# Epoch 66: Train=8.866e-02 | Val=3.849e-01
# Epoch 67: Train=9.300e-02 | Val=3.397e-01
# Epoch 68: Train=8.951e-02 | Val=3.311e-01
# Epoch 69: Train=7.932e-02 | Val=3.575e-01
# Epoch 70: Train=7.381e-02 | Val=2.920e-01
# Epoch 71: Train=7.734e-02 | Val=4.025e-01
# Epoch 72: Train=9.519e-02 | Val=4.873e-01
# Epoch 73: Train=8.432e-02 | Val=3.474e-01
# Epoch 74: Train=7.150e-02 | Val=3.391e-01
# Epoch 75: Train=8.742e-02 | Val=3.819e-01
# Epoch 76: Train=7.022e-02 | Val=3.865e-01
# Epoch 77: Train=9.068e-02 | Val=3.103e-01
# Epoch 78: Train=8.497e-02 | Val=2.942e-01
# Epoch 79: Train=7.034e-02 | Val=3.434e-01
# Epoch 80: Train=6.886e-02 | Val=2.866e-01
# Epoch 81: Train=8.050e-02 | Val=3.015e-01
# Epoch 82: Train=6.111e-02 | Val=3.105e-01
# Epoch 83: Train=6.708e-02 | Val=3.271e-01
# Epoch 84: Train=6.522e-02 | Val=3.523e-01
# Epoch 85: Train=6.857e-02 | Val=2.907e-01
# Epoch 86: Train=5.737e-02 | Val=3.149e-01
# Epoch 87: Train=6.856e-02 | Val=2.783e-01
# Epoch 88: Train=5.348e-02 | Val=3.195e-01
# Epoch 89: Train=5.579e-02 | Val=3.393e-01
# Epoch 90: Train=4.747e-02 | Val=3.046e-01
# Epoch 91: Train=4.367e-02 | Val=3.414e-01
# Epoch 92: Train=4.282e-02 | Val=3.455e-01
# Epoch 93: Train=6.508e-02 | Val=3.619e-01
# Epoch 94: Train=8.859e-02 | Val=3.295e-01
# Epoch 95: Train=6.513e-02 | Val=3.444e-01
# Epoch 96: Train=5.385e-02 | Val=2.744e-01
# Epoch 97: Train=6.936e-02 | Val=3.409e-01
# Epoch 98: Train=4.779e-02 | Val=3.165e-01
# Epoch 99: Train=4.129e-02 | Val=3.586e-01
# Epoch 100: Train=4.547e-02 | Val=3.239e-01
# CNN(
#   (conv): Sequential(
#     (0): Conv3d(2, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): GroupNorm(8, 32, eps=1e-05, affine=True)
#     (2): ReLU()
#     (3): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (5): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (6): ReLU()
#     (7): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (9): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (10): ReLU()
#     (11): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (pool): AdaptiveAvgPool3d(output_size=1)
#   (fc): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
evaluate_model(
        model, te_loader, test_ds,
        y_mean, y_std,
        vlin_baseline, rho_vlin
    )
