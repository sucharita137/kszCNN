# %%
import sys
import os
import numpy as np
import torch
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import train_test_split
from scipy.stats import pearsonr

# %%
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from kszcnn.simplified_cnn_pos import *

# %%
np.random.seed(SEED)
torch.manual_seed(SEED)

# %%
#  1. Load grids
grid_train, grid_test = memmap_grid_slices(
    GRID_FILE, [TRAIN_REAL_IDX, TEST_REAL_IDX]
)

print("Grid shapes:", grid_train.shape, grid_test.shape)
# Out:
# Grid shapes: (128, 128, 128) (128, 128, 128)

# %%
# 2. Smooth density
delta_train = smooth_density_kspace(grid_train, SMOOTH_SCALE)
delta_test  = smooth_density_kspace(grid_test, SMOOTH_SCALE)

# %%
#  3. Normalize
mean = delta_train.mean()
std  = delta_train.std() + 1e-12

delta_train = (delta_train - mean) / std
delta_test  = (delta_test - mean) / std

# %%
# 4. Load halos
pos_tr, vel_tr, mass_tr = load_halos(TRAIN_HALO_FILE)
pos_te, vel_te, mass_te = load_halos(TEST_HALO_FILE)

print("Halos:", len(pos_tr), len(pos_te))
# Out:
# Halos: 20817 21205

# %%
#  5. Dataset 
rng = np.random.RandomState(SEED)
train_ds_full = HaloDataset(
    delta_train,
    pos_tr,
    vel_tr,
    mass_tr,
    mass_cut=MASS_CUT, max_n=MAX_HALOS,
    rng=rng
)

test_ds = HaloDataset(
    delta_test,
    pos_te,
    vel_te,
    mass_te,
    mass_cut=MASS_CUT, max_n=MAX_HALOS,
    rng=rng
)
# Out:
# Selected halos: 547
# Selected halos: 569

# %%
#  6. Linear baseline 
vlin_test = compute_vlin_from_density(
    grid_test,R_smooth=SMOOTH_SCALE
)

vlin_baseline = vlin_at_halos(vlin_test, test_ds.pos)

rho_vlin = pearsonr(test_ds.vz, vlin_baseline)[0]

print("Linear theory correlation:", rho_vlin)
# Out:
# Linear theory correlation: 0.8551195

# %%
#7. Train / validation
idxs = np.arange(len(train_ds_full))

tr_idx, val_idx = train_test_split(
    idxs,
    test_size=0.2,
    random_state=SEED
)

tr_ds  = Subset(train_ds_full, tr_idx)
val_ds = Subset(train_ds_full, val_idx)

# %%
#  8. Loaders
tr_loader = DataLoader(tr_ds, batch_size=BATCH, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH)
te_loader  = DataLoader(test_ds, batch_size=BATCH)

# %%
#  9. Normalize velocity
y_train = np.array([train_ds_full[i][1] for i in tr_idx])

y_mean = y_train.mean()
y_std  = y_train.std() + 1e-12

print("Velocity mean/std:", y_mean, y_std)
# Out:
# Velocity mean/std: -1.0862699 105.11467

# %%
model = CNN().to(DEVICE)

# %%
train_model(
        model, tr_loader, val_loader, y_mean, y_std
    )
# Out:
# Epoch 1: Train=3.735e-01 | Val=8.041e-01
# Epoch 2: Train=3.521e-01 | Val=8.350e-01
# Epoch 3: Train=3.043e-01 | Val=6.901e-01
# Epoch 4: Train=2.660e-01 | Val=8.496e-01
# Epoch 5: Train=2.482e-01 | Val=6.264e-01
# Epoch 6: Train=2.360e-01 | Val=6.183e-01
# Epoch 7: Train=2.052e-01 | Val=6.258e-01
# Epoch 8: Train=2.126e-01 | Val=6.031e-01
# Epoch 9: Train=2.229e-01 | Val=6.337e-01
# Epoch 10: Train=2.026e-01 | Val=5.559e-01
# Epoch 11: Train=2.183e-01 | Val=6.075e-01
# Epoch 12: Train=1.975e-01 | Val=5.657e-01
# Epoch 13: Train=1.907e-01 | Val=4.910e-01
# Epoch 14: Train=1.804e-01 | Val=6.091e-01
# Epoch 15: Train=1.751e-01 | Val=4.765e-01
# Epoch 16: Train=1.727e-01 | Val=5.089e-01
# Epoch 17: Train=1.738e-01 | Val=5.119e-01
# Epoch 18: Train=1.836e-01 | Val=5.971e-01
# Epoch 19: Train=1.738e-01 | Val=5.398e-01
# Epoch 20: Train=1.803e-01 | Val=4.505e-01
# Epoch 21: Train=1.699e-01 | Val=5.058e-01
# Epoch 22: Train=1.893e-01 | Val=4.564e-01
# Epoch 23: Train=1.694e-01 | Val=4.371e-01
# Epoch 24: Train=1.529e-01 | Val=4.427e-01
# Epoch 25: Train=1.513e-01 | Val=4.735e-01
# Epoch 26: Train=1.625e-01 | Val=4.273e-01
# Epoch 27: Train=1.637e-01 | Val=4.174e-01
# Epoch 28: Train=1.670e-01 | Val=4.241e-01
# Epoch 29: Train=1.524e-01 | Val=4.392e-01
# Epoch 30: Train=1.595e-01 | Val=4.777e-01
# Epoch 31: Train=1.421e-01 | Val=4.797e-01
# Epoch 32: Train=1.351e-01 | Val=3.973e-01
# Epoch 33: Train=1.397e-01 | Val=3.874e-01
# Epoch 34: Train=1.378e-01 | Val=3.893e-01
# Epoch 35: Train=1.460e-01 | Val=4.804e-01
# Epoch 36: Train=1.545e-01 | Val=3.748e-01
# Epoch 37: Train=1.394e-01 | Val=4.101e-01
# Epoch 38: Train=1.375e-01 | Val=4.567e-01
# Epoch 39: Train=1.524e-01 | Val=5.918e-01
# Epoch 40: Train=1.549e-01 | Val=4.723e-01
# Epoch 41: Train=1.471e-01 | Val=4.975e-01
# Epoch 42: Train=1.395e-01 | Val=5.454e-01
# Epoch 43: Train=1.404e-01 | Val=3.773e-01
# Epoch 44: Train=1.496e-01 | Val=4.070e-01
# Epoch 45: Train=1.499e-01 | Val=4.035e-01
# Epoch 46: Train=1.303e-01 | Val=4.973e-01
# Epoch 47: Train=1.474e-01 | Val=4.966e-01
# Epoch 48: Train=1.315e-01 | Val=4.849e-01
# Epoch 49: Train=1.319e-01 | Val=6.544e-01
# Epoch 50: Train=1.453e-01 | Val=4.374e-01
# Epoch 51: Train=1.349e-01 | Val=4.334e-01
# Epoch 52: Train=1.436e-01 | Val=3.685e-01
# Epoch 53: Train=1.199e-01 | Val=3.790e-01
# Epoch 54: Train=1.308e-01 | Val=3.888e-01
# Epoch 55: Train=1.243e-01 | Val=4.248e-01
# Epoch 56: Train=1.109e-01 | Val=5.759e-01
# Epoch 57: Train=1.404e-01 | Val=4.845e-01
# Epoch 58: Train=1.261e-01 | Val=4.374e-01
# Epoch 59: Train=1.178e-01 | Val=4.285e-01
# Epoch 60: Train=1.359e-01 | Val=4.074e-01
# Epoch 61: Train=1.053e-01 | Val=3.787e-01
# Epoch 62: Train=1.056e-01 | Val=3.992e-01
# Epoch 63: Train=1.188e-01 | Val=3.763e-01
# Epoch 64: Train=1.105e-01 | Val=4.293e-01
# Epoch 65: Train=1.345e-01 | Val=3.818e-01
# Epoch 66: Train=1.288e-01 | Val=4.302e-01
# Epoch 67: Train=1.049e-01 | Val=4.421e-01
# Epoch 68: Train=1.085e-01 | Val=4.068e-01
# Epoch 69: Train=1.074e-01 | Val=4.163e-01
# Epoch 70: Train=1.235e-01 | Val=3.821e-01
# Epoch 71: Train=1.046e-01 | Val=3.959e-01
# Epoch 72: Train=1.109e-01 | Val=4.804e-01
# Epoch 73: Train=1.002e-01 | Val=3.691e-01
# Epoch 74: Train=9.828e-02 | Val=3.836e-01
# Epoch 75: Train=9.670e-02 | Val=3.677e-01
# Epoch 76: Train=9.435e-02 | Val=3.969e-01
# Epoch 77: Train=1.123e-01 | Val=4.202e-01
# Epoch 78: Train=9.251e-02 | Val=4.729e-01
# Epoch 79: Train=1.035e-01 | Val=3.783e-01
# Epoch 80: Train=9.616e-02 | Val=4.209e-01
# Epoch 81: Train=1.109e-01 | Val=3.922e-01
# Epoch 82: Train=9.863e-02 | Val=3.749e-01
# Epoch 83: Train=9.340e-02 | Val=3.801e-01
# Epoch 84: Train=9.620e-02 | Val=3.646e-01
# Epoch 85: Train=9.504e-02 | Val=3.499e-01
# Epoch 86: Train=8.916e-02 | Val=4.322e-01
# Epoch 87: Train=1.181e-01 | Val=4.032e-01
# Epoch 88: Train=8.773e-02 | Val=4.007e-01
# Epoch 89: Train=1.058e-01 | Val=4.212e-01
# Epoch 90: Train=1.005e-01 | Val=4.078e-01
# Epoch 91: Train=1.019e-01 | Val=4.931e-01
# Epoch 92: Train=9.629e-02 | Val=4.405e-01
# Epoch 93: Train=8.405e-02 | Val=3.863e-01
# Epoch 94: Train=8.837e-02 | Val=3.732e-01
# Epoch 95: Train=8.467e-02 | Val=4.017e-01
# Epoch 96: Train=8.022e-02 | Val=4.094e-01
# Epoch 97: Train=8.642e-02 | Val=4.177e-01
# Epoch 98: Train=9.859e-02 | Val=4.275e-01
# Epoch 99: Train=9.166e-02 | Val=5.493e-01
# Epoch 100: Train=9.681e-02 | Val=3.979e-01
# CNN(
#   (conv): Sequential(
#     (0): Conv3d(3, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): GroupNorm(8, 32, eps=1e-05, affine=True)
#     (2): ReLU()
#     (3): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (5): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (6): ReLU()
#     (7): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (9): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (10): ReLU()
#     (11): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (pool): AdaptiveAvgPool3d(output_size=1)
#   (fc): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
evaluate_model(
        model, te_loader, test_ds,
        y_mean, y_std,
        vlin_baseline, rho_vlin
    )
# Out:
# ===== TEST RESULTS =====
# N = 569
# RMSE = 59.506
# RMS(true) = 96.798
# RMS(pred) = 84.722
