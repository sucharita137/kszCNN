# %%
import sys
import os
import numpy as np
import torch
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import train_test_split
from scipy.stats import pearsonr

# %%
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from kszcnn.simplified_cnn_err_density import *

# %%
np.random.seed(SEED)
torch.manual_seed(SEED)

# %%
#  1. Load grids
grid_train, grid_test = memmap_grid_slices(
    GRID_FILE, [TRAIN_REAL_IDX, TEST_REAL_IDX]
)

print("Grid shapes:", grid_train.shape, grid_test.shape)
# Out:
# Grid shapes: (128, 128, 128) (128, 128, 128)

# %%
# 2. Smooth density
delta_train = smooth_density_kspace(grid_train, SMOOTH_SCALE)
delta_test  = smooth_density_kspace(grid_test, SMOOTH_SCALE)

# %%
#  3. Normalize
mean = delta_train.mean()
std  = delta_train.std() + 1e-12

delta_train = (delta_train - mean) / std
delta_test  = (delta_test - mean) / std

# %%
# 4. Load halos
pos_tr, vel_tr, mass_tr = load_halos(TRAIN_HALO_FILE)
pos_te, vel_te, mass_te = load_halos(TEST_HALO_FILE)

pos_tr = redshift_err(pos_tr, sigma_z=1e-4)
pos_te = redshift_err(pos_te, sigma_z=1e-4)


print("Halos:", len(pos_tr), len(pos_te))
# Out:
# Halos: 20817 21205

# %%
#  5. Dataset 
rng = np.random.RandomState(SEED)
train_ds_full = HaloDataset(
    delta_train,
    pos_tr,
    vel_tr,
    mass_tr,
    mass_cut=MASS_CUT, max_n=MAX_HALOS,
    rng=rng
)

test_ds = HaloDataset(
    delta_test,
    pos_te,
    vel_te,
    mass_te,
    mass_cut=MASS_CUT, max_n=MAX_HALOS,
    rng=rng
)
# Out:
# Selected halos: 547
# Selected halos: 569

# %%
#  6. Linear baseline 
vlin_test = compute_vlin_from_density(
    grid_test,R_smooth=SMOOTH_SCALE
)

vlin_baseline = vlin_at_halos(vlin_test, test_ds.pos)

rho_vlin = pearsonr(test_ds.vz, vlin_baseline)[0]

print("Linear theory correlation:", rho_vlin)
# Out:
# Linear theory correlation: 0.8239114

# %%
#7. Train / validation
idxs = np.arange(len(train_ds_full))

tr_idx, val_idx = train_test_split(
    idxs,
    test_size=0.2,
    random_state=SEED
)

tr_ds  = Subset(train_ds_full, tr_idx)
val_ds = Subset(train_ds_full, val_idx)

# %%
#  8. Loaders
tr_loader = DataLoader(tr_ds, batch_size=BATCH, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH)
te_loader  = DataLoader(test_ds, batch_size=BATCH)

# %%
#  9. Normalize velocity
y_train = np.array([train_ds_full[i][1] for i in tr_idx])

y_mean = y_train.mean()
y_std  = y_train.std() + 1e-12

print("Velocity mean/std:", y_mean, y_std)
# Out:
# Velocity mean/std: -1.0862699 105.11467

# %%
model = CNN().to(DEVICE)

# %%
train_model(
        model, tr_loader, val_loader, y_mean, y_std
    )
# Out:
# Epoch 1: Train=3.094e-01 | Val=4.893e-01
# Epoch 2: Train=2.346e-01 | Val=4.270e-01
# Epoch 3: Train=2.068e-01 | Val=3.841e-01
# Epoch 4: Train=1.998e-01 | Val=4.236e-01
# Epoch 5: Train=2.021e-01 | Val=4.150e-01
# Epoch 6: Train=1.953e-01 | Val=3.550e-01
# Epoch 7: Train=1.946e-01 | Val=4.539e-01
# Epoch 8: Train=1.883e-01 | Val=3.441e-01
# Epoch 9: Train=1.827e-01 | Val=3.701e-01
# Epoch 10: Train=1.807e-01 | Val=3.263e-01
# Epoch 11: Train=1.897e-01 | Val=3.529e-01
# Epoch 12: Train=1.753e-01 | Val=3.637e-01
# Epoch 13: Train=1.732e-01 | Val=3.337e-01
# Epoch 14: Train=1.714e-01 | Val=4.136e-01
# Epoch 15: Train=1.899e-01 | Val=3.649e-01
# Epoch 16: Train=1.707e-01 | Val=4.155e-01
# Epoch 17: Train=1.696e-01 | Val=3.497e-01
# Epoch 18: Train=1.688e-01 | Val=2.926e-01
# Epoch 19: Train=1.564e-01 | Val=2.899e-01
# Epoch 20: Train=1.549e-01 | Val=3.166e-01
# Epoch 21: Train=1.563e-01 | Val=2.872e-01
# Epoch 22: Train=1.534e-01 | Val=2.705e-01
# Epoch 23: Train=1.544e-01 | Val=2.909e-01
# Epoch 24: Train=1.535e-01 | Val=2.714e-01
# Epoch 25: Train=1.490e-01 | Val=2.966e-01
# Epoch 26: Train=1.673e-01 | Val=3.092e-01
# Epoch 27: Train=1.548e-01 | Val=2.741e-01
# Epoch 28: Train=1.427e-01 | Val=2.811e-01
# Epoch 29: Train=1.566e-01 | Val=2.702e-01
# Epoch 30: Train=1.394e-01 | Val=2.798e-01
# Epoch 31: Train=1.446e-01 | Val=3.251e-01
# Epoch 32: Train=1.563e-01 | Val=5.249e-01
# Epoch 33: Train=1.687e-01 | Val=3.429e-01
# Epoch 34: Train=1.411e-01 | Val=2.477e-01
# Epoch 35: Train=1.298e-01 | Val=3.001e-01
# Epoch 36: Train=1.292e-01 | Val=2.953e-01
# Epoch 37: Train=1.470e-01 | Val=3.225e-01
# Epoch 38: Train=1.299e-01 | Val=2.588e-01
# Epoch 39: Train=1.216e-01 | Val=2.623e-01
# Epoch 40: Train=1.259e-01 | Val=2.327e-01
# Epoch 41: Train=1.390e-01 | Val=2.493e-01
# Epoch 42: Train=1.272e-01 | Val=2.423e-01
# Epoch 43: Train=1.208e-01 | Val=2.405e-01
# Epoch 44: Train=1.166e-01 | Val=2.662e-01
# Epoch 45: Train=1.217e-01 | Val=2.325e-01
# Epoch 46: Train=1.144e-01 | Val=2.924e-01
# Epoch 47: Train=1.205e-01 | Val=2.304e-01
# Epoch 48: Train=1.143e-01 | Val=2.427e-01
# Epoch 49: Train=1.074e-01 | Val=2.362e-01
# Epoch 50: Train=1.279e-01 | Val=2.372e-01
# Epoch 51: Train=1.253e-01 | Val=2.644e-01
# Epoch 52: Train=1.304e-01 | Val=2.626e-01
# Epoch 53: Train=1.119e-01 | Val=2.207e-01
# Epoch 54: Train=1.077e-01 | Val=2.157e-01
# Epoch 55: Train=1.225e-01 | Val=2.277e-01
# Epoch 56: Train=1.113e-01 | Val=2.688e-01
# Epoch 57: Train=1.083e-01 | Val=2.801e-01
# Epoch 58: Train=1.149e-01 | Val=2.346e-01
# Epoch 59: Train=1.130e-01 | Val=2.234e-01
# Epoch 60: Train=9.640e-02 | Val=2.333e-01
# Epoch 61: Train=1.019e-01 | Val=2.575e-01
# Epoch 62: Train=1.041e-01 | Val=2.631e-01
# Epoch 63: Train=9.467e-02 | Val=2.159e-01
# Epoch 64: Train=1.019e-01 | Val=2.265e-01
# Epoch 65: Train=9.737e-02 | Val=2.519e-01
# Epoch 66: Train=1.089e-01 | Val=2.029e-01
# Epoch 67: Train=1.183e-01 | Val=2.365e-01
# Epoch 68: Train=9.545e-02 | Val=2.360e-01
# Epoch 69: Train=9.233e-02 | Val=2.214e-01
# Epoch 70: Train=8.873e-02 | Val=2.026e-01
# Epoch 71: Train=8.747e-02 | Val=2.319e-01
# Epoch 72: Train=9.280e-02 | Val=2.094e-01
# Epoch 73: Train=9.159e-02 | Val=2.201e-01
# Epoch 74: Train=1.025e-01 | Val=2.740e-01
# Epoch 75: Train=9.054e-02 | Val=2.074e-01
# Epoch 76: Train=8.345e-02 | Val=3.283e-01
# Epoch 77: Train=1.136e-01 | Val=2.127e-01
# Epoch 78: Train=8.507e-02 | Val=2.731e-01
# Epoch 79: Train=9.453e-02 | Val=2.532e-01
# Epoch 80: Train=8.669e-02 | Val=2.166e-01
# Epoch 81: Train=8.238e-02 | Val=2.046e-01
# Epoch 82: Train=8.932e-02 | Val=2.373e-01
# Epoch 83: Train=9.115e-02 | Val=2.196e-01
# Epoch 84: Train=7.583e-02 | Val=2.258e-01
# Epoch 85: Train=7.083e-02 | Val=2.124e-01
# Epoch 86: Train=6.980e-02 | Val=2.153e-01
# Epoch 87: Train=7.027e-02 | Val=2.531e-01
# Epoch 88: Train=7.674e-02 | Val=2.443e-01
# Epoch 89: Train=8.168e-02 | Val=2.498e-01
# Epoch 90: Train=7.857e-02 | Val=2.378e-01
# Epoch 91: Train=7.932e-02 | Val=2.301e-01
# Epoch 92: Train=8.167e-02 | Val=2.505e-01
# Epoch 93: Train=7.312e-02 | Val=2.273e-01
# Epoch 94: Train=7.345e-02 | Val=2.343e-01
# Epoch 95: Train=8.894e-02 | Val=3.048e-01
# Epoch 96: Train=9.058e-02 | Val=2.741e-01
# Epoch 97: Train=6.968e-02 | Val=2.549e-01
# Epoch 98: Train=7.618e-02 | Val=2.506e-01
# Epoch 99: Train=6.897e-02 | Val=2.131e-01
# Epoch 100: Train=6.405e-02 | Val=2.429e-01
# CNN(
#   (conv): Sequential(
#     (0): Conv3d(1, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): GroupNorm(8, 32, eps=1e-05, affine=True)
#     (2): ReLU()
#     (3): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (5): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (6): ReLU()
#     (7): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (9): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (10): ReLU()
#     (11): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (pool): AdaptiveAvgPool3d(output_size=1)
#   (fc): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
evaluate_model(
        model, te_loader, test_ds,
        y_mean, y_std,
        vlin_baseline, rho_vlin
    )
# Out:
# p68 = 34.163776
# p95 = 96.81837
# p99 = 182.17258
# ===== TEST RESULTS =====
# N = 569
# RMSE = 50.032
# RMS(true) = 96.798
# RMS(pred) = 88.566
