# %%
import sys
import os
import numpy as np
import torch
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import train_test_split
from scipy.stats import pearsonr

# %%
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from kszcnn.simplified_cnn_err_density import *

# %%
np.random.seed(SEED)
torch.manual_seed(SEED)

# %%
#  1. Load grids
grid_train, grid_test = memmap_grid_slices(
    GRID_FILE, [TRAIN_REAL_IDX, TEST_REAL_IDX]
)

print("Grid shapes:", grid_train.shape, grid_test.shape)
# Out:
# Grid shapes: (128, 128, 128) (128, 128, 128)

# %%
# 2. Smooth density
delta_train = smooth_density_kspace(grid_train, SMOOTH_SCALE)
delta_test  = smooth_density_kspace(grid_test, SMOOTH_SCALE)

# %%
#  3. Normalize
mean = delta_train.mean()
std  = delta_train.std() + 1e-12

delta_train = (delta_train - mean) / std
delta_test  = (delta_test - mean) / std

# %%
# 4. Load halos
pos_tr, vel_tr, mass_tr = load_halos(TRAIN_HALO_FILE)
pos_te, vel_te, mass_te = load_halos(TEST_HALO_FILE)

pos_tr = redshift_err(pos_tr, sigma_z=0.1)
pos_te = redshift_err(pos_te, sigma_z=0.1)


print("Halos:", len(pos_tr), len(pos_te))
# Out:
# Halos: 20817 21205

# %%
#  5. Dataset 
rng = np.random.RandomState(SEED)
train_ds_full = HaloDataset(
    delta_train,
    pos_tr,
    vel_tr,
    mass_tr,
    mass_cut=MASS_CUT, max_n=MAX_HALOS,
    rng=rng
)

test_ds = HaloDataset(
    delta_test,
    pos_te,
    vel_te,
    mass_te,
    mass_cut=MASS_CUT, max_n=MAX_HALOS,
    rng=rng
)
# Out:
# Selected halos: 547
# Selected halos: 569

# %%
#  6. Linear baseline 
vlin_test = compute_vlin_from_density(
    grid_test,R_smooth=SMOOTH_SCALE
)

vlin_baseline = vlin_at_halos(vlin_test, test_ds.pos)

rho_vlin = pearsonr(test_ds.vz, vlin_baseline)[0]

print("Linear theory correlation:", rho_vlin)
# Out:
# Linear theory correlation: -0.07529198

# %%
#7. Train / validation
idxs = np.arange(len(train_ds_full))

tr_idx, val_idx = train_test_split(
    idxs,
    test_size=0.2,
    random_state=SEED
)

tr_ds  = Subset(train_ds_full, tr_idx)
val_ds = Subset(train_ds_full, val_idx)

# %%
#  8. Loaders
tr_loader = DataLoader(tr_ds, batch_size=BATCH, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH)
te_loader  = DataLoader(test_ds, batch_size=BATCH)

# %%
#  9. Normalize velocity
y_train = np.array([train_ds_full[i][1] for i in tr_idx])

y_mean = y_train.mean()
y_std  = y_train.std() + 1e-12

print("Velocity mean/std:", y_mean, y_std)
# Out:
# Velocity mean/std: -1.0862699 105.11467

# %%
model = CNN().to(DEVICE)

# %%
train_model(
        model, tr_loader, val_loader, y_mean, y_std
    )
# Out:
# Epoch 1: Train=4.052e-01 | Val=9.713e-01
# Epoch 2: Train=3.908e-01 | Val=9.661e-01
# Epoch 3: Train=3.903e-01 | Val=9.668e-01
# Epoch 4: Train=3.902e-01 | Val=9.674e-01
# Epoch 5: Train=3.877e-01 | Val=9.685e-01
# Epoch 6: Train=3.867e-01 | Val=9.733e-01
# Epoch 7: Train=3.899e-01 | Val=9.716e-01
# Epoch 8: Train=3.860e-01 | Val=9.747e-01
# Epoch 9: Train=3.905e-01 | Val=9.740e-01
# Epoch 10: Train=3.853e-01 | Val=9.875e-01
# Epoch 11: Train=3.864e-01 | Val=9.974e-01
# Epoch 12: Train=3.833e-01 | Val=9.814e-01
# Epoch 13: Train=3.825e-01 | Val=9.801e-01
# Epoch 14: Train=3.816e-01 | Val=9.934e-01
# Epoch 15: Train=3.832e-01 | Val=9.908e-01
# Epoch 16: Train=3.790e-01 | Val=9.953e-01
# Epoch 17: Train=3.819e-01 | Val=1.036e+00
# Epoch 18: Train=3.796e-01 | Val=9.842e-01
# Epoch 19: Train=3.797e-01 | Val=1.003e+00
# Epoch 20: Train=3.787e-01 | Val=1.002e+00
# Epoch 21: Train=3.804e-01 | Val=1.004e+00
# Epoch 22: Train=3.762e-01 | Val=1.009e+00
# Epoch 23: Train=3.697e-01 | Val=1.023e+00
# Epoch 24: Train=3.688e-01 | Val=1.016e+00
# Epoch 25: Train=3.693e-01 | Val=1.014e+00
# Epoch 26: Train=3.665e-01 | Val=9.961e-01
# Epoch 27: Train=3.621e-01 | Val=1.049e+00
# Epoch 28: Train=3.716e-01 | Val=9.966e-01
# Epoch 29: Train=3.625e-01 | Val=1.023e+00
# Epoch 30: Train=3.634e-01 | Val=1.005e+00
# Epoch 31: Train=3.636e-01 | Val=1.029e+00
# Epoch 32: Train=3.571e-01 | Val=1.034e+00
# Epoch 33: Train=3.592e-01 | Val=1.048e+00
# Epoch 34: Train=3.570e-01 | Val=1.019e+00
# Epoch 35: Train=3.525e-01 | Val=1.038e+00
# Epoch 36: Train=3.481e-01 | Val=1.072e+00
# Epoch 37: Train=3.460e-01 | Val=1.050e+00
# Epoch 38: Train=3.462e-01 | Val=1.030e+00
# Epoch 39: Train=3.504e-01 | Val=1.075e+00
# Epoch 40: Train=3.467e-01 | Val=1.087e+00
# Epoch 41: Train=3.395e-01 | Val=1.057e+00
# Epoch 42: Train=3.420e-01 | Val=1.155e+00
# Epoch 43: Train=3.453e-01 | Val=1.072e+00
# Epoch 44: Train=3.470e-01 | Val=1.087e+00
# Epoch 45: Train=3.368e-01 | Val=1.171e+00
# Epoch 46: Train=3.255e-01 | Val=1.101e+00
# Epoch 47: Train=3.337e-01 | Val=1.134e+00
# Epoch 48: Train=3.282e-01 | Val=1.117e+00
# Epoch 49: Train=3.265e-01 | Val=1.105e+00
# Epoch 50: Train=3.429e-01 | Val=1.048e+00
# Epoch 51: Train=3.241e-01 | Val=1.111e+00
# Epoch 52: Train=3.195e-01 | Val=1.150e+00
# Epoch 53: Train=3.267e-01 | Val=1.063e+00
# Epoch 54: Train=3.152e-01 | Val=1.055e+00
# Epoch 55: Train=3.123e-01 | Val=1.167e+00
# Epoch 56: Train=3.218e-01 | Val=1.105e+00
# Epoch 57: Train=3.282e-01 | Val=1.092e+00
# Epoch 58: Train=3.185e-01 | Val=1.111e+00
# Epoch 59: Train=3.111e-01 | Val=1.099e+00
# Epoch 60: Train=2.981e-01 | Val=1.140e+00
# Epoch 61: Train=3.054e-01 | Val=1.133e+00
# Epoch 62: Train=3.076e-01 | Val=1.116e+00
# Epoch 63: Train=2.916e-01 | Val=1.227e+00
# Epoch 64: Train=3.013e-01 | Val=1.144e+00
# Epoch 65: Train=2.965e-01 | Val=1.124e+00
# Epoch 66: Train=2.884e-01 | Val=1.180e+00
# Epoch 67: Train=2.978e-01 | Val=1.109e+00
# Epoch 68: Train=3.062e-01 | Val=1.134e+00
# Epoch 69: Train=2.875e-01 | Val=1.092e+00
# Epoch 70: Train=2.898e-01 | Val=1.154e+00
# Epoch 71: Train=2.977e-01 | Val=1.088e+00
# Epoch 72: Train=2.745e-01 | Val=1.205e+00
# Epoch 73: Train=2.778e-01 | Val=1.121e+00
# Epoch 74: Train=2.862e-01 | Val=1.073e+00
# Epoch 75: Train=2.782e-01 | Val=1.165e+00
# Epoch 76: Train=2.623e-01 | Val=1.077e+00
# Epoch 77: Train=2.739e-01 | Val=1.167e+00
# Epoch 78: Train=2.923e-01 | Val=1.079e+00
# Epoch 79: Train=2.679e-01 | Val=1.091e+00
# Epoch 80: Train=2.558e-01 | Val=1.139e+00
# Epoch 81: Train=2.543e-01 | Val=1.236e+00
# Epoch 82: Train=2.602e-01 | Val=1.151e+00
# Epoch 83: Train=2.611e-01 | Val=1.276e+00
# Epoch 84: Train=2.461e-01 | Val=1.174e+00
# Epoch 85: Train=2.516e-01 | Val=1.242e+00
# Epoch 86: Train=2.517e-01 | Val=1.142e+00
# Epoch 87: Train=2.347e-01 | Val=1.247e+00
# Epoch 88: Train=2.485e-01 | Val=1.149e+00
# Epoch 89: Train=2.254e-01 | Val=1.117e+00
# Epoch 90: Train=2.235e-01 | Val=1.334e+00
# Epoch 91: Train=2.472e-01 | Val=1.173e+00
# Epoch 92: Train=2.326e-01 | Val=1.206e+00
# Epoch 93: Train=2.249e-01 | Val=1.170e+00
# Epoch 94: Train=2.231e-01 | Val=1.210e+00
# Epoch 95: Train=2.134e-01 | Val=1.160e+00
# Epoch 96: Train=2.100e-01 | Val=1.211e+00
# Epoch 97: Train=2.067e-01 | Val=1.245e+00
# Epoch 98: Train=2.051e-01 | Val=1.217e+00
# Epoch 99: Train=2.253e-01 | Val=1.192e+00
# Epoch 100: Train=2.040e-01 | Val=1.274e+00
# CNN(
#   (conv): Sequential(
#     (0): Conv3d(1, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): GroupNorm(8, 32, eps=1e-05, affine=True)
#     (2): ReLU()
#     (3): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (5): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (6): ReLU()
#     (7): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (9): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (10): ReLU()
#     (11): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (pool): AdaptiveAvgPool3d(output_size=1)
#   (fc): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
evaluate_model(
        model, te_loader, test_ds,
        y_mean, y_std,
        vlin_baseline, rho_vlin
    )
# Out:
# ===== TEST RESULTS =====
# N = 569
# RMSE = 97.067
# RMS(true) = 96.798
# RMS(pred) = 0.795
