# %%
import sys
import os
import numpy as np
import torch
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import train_test_split
from scipy.stats import pearsonr

# %%
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from kszcnn.same_real_cnn_galaxy_overdensity_pres import *

# %%
train_sets, test_sets = get_experiment_sets("same_real")
title = make_title("1P_0", input_type="overdensity+pres", exp_type="same_real")

# %%
print("GRID_FILE:", GRID_P_FILE)
print("SET:", set_name)
print("HALO_FILE:", HALO_FILE)
# Out:
# GRID_FILE: /home/sucharita/kszCNN/data/Grids_P_IllustrisTNG_1P_128_z=0.0.npy
# SET: 1P_0
# HALO_FILE: /home/sucharita/kszCNN/data/groups_090_1P_0.hdf5

# %%
np.random.seed(SEED)
torch.manual_seed(SEED)

# %%
# load halos + subhalos
pos, vel, mass, sub_pos, sub_mstar = \
    load_groups_and_subhalos(HALO_FILE)

# build galaxy overdensity field 
density_grid = build_galaxy_density_grid(
    sub_pos,
    sub_mstar,
    Ngrid=128,
    mstar_cut=1e8
)

# smooth 
density_grid = smooth_delta_field(density_grid, SMOOTH_SCALE)
grid_p = memmap_grid_slices(GRID_P_FILE, [REAL_IDX])[0]
print("Grid shapes:", grid_p.shape)
# Out:
# Selected galaxies: 923
# Grid shapes: (128, 128, 128)

# %%
#  5. Dataset 
rng = np.random.RandomState(SEED)
full_ds = HaloDataset(density_grid, pos, vel, mass,grid_p,
                      mass_cut=MASS_CUT, rng=rng)

#  split 
idxs = np.arange(len(full_ds))

train_idx, test_idx = train_test_split(
    idxs, test_size=0.2, random_state=SEED
)

train_idx, val_idx = train_test_split(
    train_idx, test_size=0.2, random_state=SEED
)
# Out:
# Number of halos above mass 1e11: 547

# %%
train_ds = Subset(full_ds, train_idx)
val_ds   = Subset(full_ds, val_idx)
test_ds  = Subset(full_ds, test_idx)

# %%
tr_loader = DataLoader(train_ds, batch_size=BATCH, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH)
te_loader  = DataLoader(test_ds, batch_size=BATCH)

# %%
#  9. Normalize velocity
y_train = np.array([full_ds[i][1] for i in train_idx])

y_mean = y_train.mean()
y_std  = y_train.std() + 1e-12

print("Velocity mean/std:", y_mean, y_std)
# Out:
# Velocity mean/std: 0.36430642 107.621216

# %%
#  6. Linear baseline 

vlin_grid = compute_vlin_from_delta(
    density_grid,   # full box
    R_smooth=SMOOTH_SCALE
)

#  get test positions 
test_pos = full_ds.pos[test_idx]
test_vz  = full_ds.vz[test_idx]

#  sample 
vlin_baseline = vlin_at_halos(
    vlin_grid,
    test_pos
)

# correlation
rho_vlin = pearsonr(test_vz, vlin_baseline)[0]

print("Linear theory correlation (δg):", rho_vlin)
# Out:
# Linear theory correlation (δg): 0.83614224

# %%
model = CNN().to(DEVICE)

# %%
train_model(
        model, tr_loader, val_loader, y_mean, y_std
    )
# Out:
# Epoch 1: Train=5.163e-01 | Val=7.529e-01
# Epoch 2: Train=4.852e-01 | Val=7.424e-01
# Epoch 3: Train=4.610e-01 | Val=6.382e-01
# Epoch 4: Train=3.969e-01 | Val=7.591e-01
# Epoch 5: Train=3.763e-01 | Val=4.475e-01
# Epoch 6: Train=3.168e-01 | Val=4.269e-01
# Epoch 7: Train=2.809e-01 | Val=4.841e-01
# Epoch 8: Train=2.873e-01 | Val=4.057e-01
# Epoch 9: Train=2.643e-01 | Val=4.807e-01
# Epoch 10: Train=2.665e-01 | Val=4.145e-01
# Epoch 11: Train=2.551e-01 | Val=3.702e-01
# Epoch 12: Train=2.647e-01 | Val=3.829e-01
# Epoch 13: Train=2.442e-01 | Val=4.646e-01
# Epoch 14: Train=2.268e-01 | Val=4.514e-01
# Epoch 15: Train=2.238e-01 | Val=4.042e-01
# Epoch 16: Train=2.125e-01 | Val=3.688e-01
# Epoch 17: Train=2.142e-01 | Val=4.041e-01
# Epoch 18: Train=1.895e-01 | Val=3.673e-01
# Epoch 19: Train=1.919e-01 | Val=3.776e-01
# Epoch 20: Train=1.672e-01 | Val=3.687e-01
# Epoch 21: Train=1.680e-01 | Val=4.101e-01
# Epoch 22: Train=1.823e-01 | Val=3.882e-01
# Epoch 23: Train=1.681e-01 | Val=3.864e-01
# Epoch 24: Train=1.599e-01 | Val=3.601e-01
# Epoch 25: Train=1.299e-01 | Val=4.442e-01
# Epoch 26: Train=1.263e-01 | Val=3.431e-01
# Epoch 27: Train=1.124e-01 | Val=3.610e-01
# Epoch 28: Train=9.580e-02 | Val=3.619e-01
# Epoch 29: Train=9.822e-02 | Val=3.762e-01
# Epoch 30: Train=9.449e-02 | Val=3.710e-01
# Epoch 31: Train=8.635e-02 | Val=3.637e-01
# Epoch 32: Train=8.466e-02 | Val=4.230e-01
# Epoch 33: Train=1.022e-01 | Val=3.564e-01
# Epoch 34: Train=7.093e-02 | Val=4.494e-01
# Epoch 35: Train=5.336e-02 | Val=4.083e-01
# Epoch 36: Train=5.543e-02 | Val=3.528e-01
# Epoch 37: Train=6.385e-02 | Val=4.912e-01
# Epoch 38: Train=8.334e-02 | Val=3.796e-01
# Epoch 39: Train=5.017e-02 | Val=3.702e-01
# Epoch 40: Train=3.482e-02 | Val=3.543e-01
# Epoch 41: Train=2.739e-02 | Val=3.516e-01
# Epoch 42: Train=2.524e-02 | Val=3.673e-01
# Epoch 43: Train=2.176e-02 | Val=3.601e-01
# Epoch 44: Train=1.600e-02 | Val=3.865e-01
# Epoch 45: Train=1.806e-02 | Val=3.941e-01
# Epoch 46: Train=1.584e-02 | Val=3.604e-01
# Epoch 47: Train=1.293e-02 | Val=3.771e-01
# Epoch 48: Train=1.184e-02 | Val=3.929e-01
# Epoch 49: Train=1.791e-02 | Val=3.928e-01
# Epoch 50: Train=2.442e-02 | Val=4.057e-01
# Epoch 51: Train=2.631e-02 | Val=3.736e-01
# Epoch 52: Train=2.282e-02 | Val=3.408e-01
# Epoch 53: Train=1.374e-02 | Val=3.756e-01
# Epoch 54: Train=6.931e-03 | Val=3.678e-01
# Epoch 55: Train=7.427e-03 | Val=3.753e-01
# Epoch 56: Train=4.228e-03 | Val=3.885e-01
# Epoch 57: Train=8.310e-03 | Val=3.829e-01
# Epoch 58: Train=8.173e-03 | Val=3.660e-01
# Epoch 59: Train=5.490e-03 | Val=3.835e-01
# Epoch 60: Train=3.437e-03 | Val=3.594e-01
# Epoch 61: Train=3.123e-03 | Val=3.747e-01
# Epoch 62: Train=2.764e-03 | Val=3.791e-01
# Epoch 63: Train=3.068e-03 | Val=3.634e-01
# Epoch 64: Train=4.200e-03 | Val=3.775e-01
# Epoch 65: Train=2.706e-03 | Val=3.697e-01
# Epoch 66: Train=2.065e-03 | Val=3.729e-01
# Epoch 67: Train=1.717e-03 | Val=3.761e-01
# Epoch 68: Train=1.337e-03 | Val=3.876e-01
# Epoch 69: Train=2.106e-03 | Val=3.735e-01
# Epoch 70: Train=1.901e-03 | Val=3.674e-01
# Epoch 71: Train=2.006e-03 | Val=3.797e-01
# Epoch 72: Train=1.106e-03 | Val=3.705e-01
# Epoch 73: Train=1.468e-03 | Val=3.750e-01
# Epoch 74: Train=2.134e-03 | Val=3.731e-01
# Epoch 75: Train=4.340e-03 | Val=3.817e-01
# Epoch 76: Train=3.031e-03 | Val=3.658e-01
# Epoch 77: Train=6.196e-03 | Val=3.872e-01
# Epoch 78: Train=9.986e-03 | Val=3.934e-01
# Epoch 79: Train=1.145e-02 | Val=3.816e-01
# Epoch 80: Train=8.420e-03 | Val=3.428e-01
# Epoch 81: Train=5.602e-03 | Val=3.910e-01
# Epoch 82: Train=3.580e-03 | Val=3.644e-01
# Epoch 83: Train=3.624e-03 | Val=3.816e-01
# Epoch 84: Train=1.502e-03 | Val=3.712e-01
# Epoch 85: Train=1.586e-03 | Val=3.676e-01
# Epoch 86: Train=1.702e-03 | Val=3.804e-01
# Epoch 87: Train=1.371e-03 | Val=3.701e-01
# Epoch 88: Train=8.988e-04 | Val=3.744e-01
# Epoch 89: Train=1.168e-03 | Val=3.674e-01
# Epoch 90: Train=6.438e-04 | Val=3.772e-01
# Epoch 91: Train=6.296e-04 | Val=3.717e-01
# Epoch 92: Train=4.397e-04 | Val=3.683e-01
# Epoch 93: Train=5.697e-04 | Val=3.741e-01
# Epoch 94: Train=4.095e-04 | Val=3.722e-01
# Epoch 95: Train=3.044e-04 | Val=3.726e-01
# Epoch 96: Train=5.492e-04 | Val=3.743e-01
# Epoch 97: Train=3.083e-04 | Val=3.679e-01
# Epoch 98: Train=4.805e-04 | Val=3.710e-01
# Epoch 99: Train=5.385e-04 | Val=3.722e-01
# Epoch 100: Train=1.138e-03 | Val=3.715e-01
# CNN(
#   (conv): Sequential(
#     (0): Conv3d(2, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): GroupNorm(8, 32, eps=1e-05, affine=True)
#     (2): ReLU()
#     (3): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (5): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (6): ReLU()
#     (7): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (9): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (10): ReLU()
#     (11): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (pool): AdaptiveAvgPool3d(output_size=1)
#   (fc): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
evaluate_model(
        model, te_loader, test_ds,
        y_mean, y_std,
        vlin_baseline, rho_vlin
    )
