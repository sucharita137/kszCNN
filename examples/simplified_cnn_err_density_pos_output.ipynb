# %%
import sys
import os
import numpy as np
import torch
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import train_test_split
from scipy.stats import pearsonr

# %%
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from kszcnn.simplified_cnn_err_density_pos import *

# %%
np.random.seed(SEED)
torch.manual_seed(SEED)

# %%
#  1. Load grids
grid_train, grid_test = memmap_grid_slices(
    GRID_FILE, [TRAIN_REAL_IDX, TEST_REAL_IDX]
)

print("Grid shapes:", grid_train.shape, grid_test.shape)
# Out:
# Grid shapes: (128, 128, 128) (128, 128, 128)

# %%
# 2. Smooth density
delta_train = smooth_density_kspace(grid_train, SMOOTH_SCALE)
delta_test  = smooth_density_kspace(grid_test, SMOOTH_SCALE)

# %%
#  3. Normalize
mean = delta_train.mean()
std  = delta_train.std() + 1e-12

delta_train = (delta_train - mean) / std
delta_test  = (delta_test - mean) / std

# %%
# 4. Load halos
pos_tr, vel_tr, mass_tr = load_halos(TRAIN_HALO_FILE)
pos_te, vel_te, mass_te = load_halos(TEST_HALO_FILE)

pos_tr = redshift_err(pos_tr, sigma_z=1e-4)
pos_te = redshift_err(pos_te, sigma_z=1e-4)


print("Halos:", len(pos_tr), len(pos_te))
# Out:
# Halos: 20817 21205

# %%
#  5. Dataset 
rng = np.random.RandomState(SEED)
train_ds_full = HaloDataset(
    delta_train,
    pos_tr,
    vel_tr,
    mass_tr,
    mass_cut=MASS_CUT, max_n=MAX_HALOS,
    rng=rng
)

test_ds = HaloDataset(
    delta_test,
    pos_te,
    vel_te,
    mass_te,
    mass_cut=MASS_CUT, max_n=MAX_HALOS,
    rng=rng
)
# Out:
# Selected halos: 547
# Selected halos: 569

# %%
#  6. Linear baseline 
vlin_test = compute_vlin_from_density(
    grid_test,R_smooth=SMOOTH_SCALE
)

vlin_baseline = vlin_at_halos(vlin_test, test_ds.pos)

rho_vlin = pearsonr(test_ds.vz, vlin_baseline)[0]

print("Linear theory correlation:", rho_vlin)
# Out:
# Linear theory correlation: 0.8239114

# %%
#7. Train / validation
idxs = np.arange(len(train_ds_full))

tr_idx, val_idx = train_test_split(
    idxs,
    test_size=0.2,
    random_state=SEED
)

tr_ds  = Subset(train_ds_full, tr_idx)
val_ds = Subset(train_ds_full, val_idx)

# %%
#  8. Loaders
tr_loader = DataLoader(tr_ds, batch_size=BATCH, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH)
te_loader  = DataLoader(test_ds, batch_size=BATCH)

# %%
#  9. Normalize velocity
y_train = np.array([train_ds_full[i][1] for i in tr_idx])

y_mean = y_train.mean()
y_std  = y_train.std() + 1e-12

print("Velocity mean/std:", y_mean, y_std)
# Out:
# Velocity mean/std: -1.0862699 105.11467

# %%
model = CNN().to(DEVICE)

# %%
train_model(
        model, tr_loader, val_loader, y_mean, y_std
    )
# Out:
# Epoch 1: Train=2.646e-01 | Val=5.518e-01
# Epoch 2: Train=1.825e-01 | Val=3.845e-01
# Epoch 3: Train=1.926e-01 | Val=3.411e-01
# Epoch 4: Train=1.596e-01 | Val=3.814e-01
# Epoch 5: Train=1.643e-01 | Val=3.371e-01
# Epoch 6: Train=1.521e-01 | Val=3.648e-01
# Epoch 7: Train=1.910e-01 | Val=3.601e-01
# Epoch 8: Train=1.530e-01 | Val=3.005e-01
# Epoch 9: Train=1.425e-01 | Val=2.884e-01
# Epoch 10: Train=1.395e-01 | Val=2.725e-01
# Epoch 11: Train=1.281e-01 | Val=2.988e-01
# Epoch 12: Train=1.254e-01 | Val=2.747e-01
# Epoch 13: Train=1.361e-01 | Val=2.972e-01
# Epoch 14: Train=1.348e-01 | Val=2.859e-01
# Epoch 15: Train=1.329e-01 | Val=2.541e-01
# Epoch 16: Train=1.292e-01 | Val=2.553e-01
# Epoch 17: Train=1.180e-01 | Val=2.214e-01
# Epoch 18: Train=1.203e-01 | Val=3.373e-01
# Epoch 19: Train=1.176e-01 | Val=2.387e-01
# Epoch 20: Train=1.227e-01 | Val=2.804e-01
# Epoch 21: Train=1.179e-01 | Val=2.543e-01
# Epoch 22: Train=1.040e-01 | Val=2.169e-01
# Epoch 23: Train=1.132e-01 | Val=2.812e-01
# Epoch 24: Train=1.115e-01 | Val=2.854e-01
# Epoch 25: Train=1.090e-01 | Val=2.793e-01
# Epoch 26: Train=1.127e-01 | Val=1.999e-01
# Epoch 27: Train=1.061e-01 | Val=2.447e-01
# Epoch 28: Train=1.069e-01 | Val=2.719e-01
# Epoch 29: Train=1.258e-01 | Val=2.154e-01
# Epoch 30: Train=1.055e-01 | Val=2.388e-01
# Epoch 31: Train=1.037e-01 | Val=2.448e-01
# Epoch 32: Train=1.198e-01 | Val=2.339e-01
# Epoch 33: Train=1.057e-01 | Val=2.226e-01
# Epoch 34: Train=9.903e-02 | Val=2.837e-01
# Epoch 35: Train=9.933e-02 | Val=3.235e-01
# Epoch 36: Train=1.338e-01 | Val=2.787e-01
# Epoch 37: Train=1.055e-01 | Val=2.527e-01
# Epoch 38: Train=1.120e-01 | Val=2.513e-01
# Epoch 39: Train=9.945e-02 | Val=2.191e-01
# Epoch 40: Train=8.781e-02 | Val=2.448e-01
# Epoch 41: Train=8.946e-02 | Val=2.631e-01
# Epoch 42: Train=1.025e-01 | Val=3.157e-01
# Epoch 43: Train=1.062e-01 | Val=2.168e-01
# Epoch 44: Train=9.258e-02 | Val=2.183e-01
# Epoch 45: Train=8.548e-02 | Val=2.270e-01
# Epoch 46: Train=8.500e-02 | Val=2.450e-01
# Epoch 47: Train=8.606e-02 | Val=2.066e-01
# Epoch 48: Train=8.984e-02 | Val=2.573e-01
# Epoch 49: Train=9.667e-02 | Val=2.277e-01
# Epoch 50: Train=9.213e-02 | Val=2.826e-01
# Epoch 51: Train=8.296e-02 | Val=2.678e-01
# Epoch 52: Train=8.799e-02 | Val=3.489e-01
# Epoch 53: Train=9.462e-02 | Val=3.099e-01
# Epoch 54: Train=9.645e-02 | Val=2.368e-01
# Epoch 55: Train=9.027e-02 | Val=3.169e-01
# Epoch 56: Train=8.363e-02 | Val=2.554e-01
# Epoch 57: Train=7.840e-02 | Val=2.839e-01
# Epoch 58: Train=9.237e-02 | Val=2.246e-01
# Epoch 59: Train=7.725e-02 | Val=2.589e-01
# Epoch 60: Train=8.122e-02 | Val=2.562e-01
# Epoch 61: Train=7.143e-02 | Val=2.670e-01
# Epoch 62: Train=7.338e-02 | Val=2.820e-01
# Epoch 63: Train=7.471e-02 | Val=2.691e-01
# Epoch 64: Train=8.164e-02 | Val=3.137e-01
# Epoch 65: Train=6.782e-02 | Val=4.301e-01
# Epoch 66: Train=9.546e-02 | Val=2.276e-01
# Epoch 67: Train=7.340e-02 | Val=2.370e-01
# Epoch 68: Train=7.228e-02 | Val=2.655e-01
# Epoch 69: Train=7.040e-02 | Val=2.964e-01
# Epoch 70: Train=7.047e-02 | Val=3.829e-01
# Epoch 71: Train=7.880e-02 | Val=3.043e-01
# Epoch 72: Train=6.297e-02 | Val=3.108e-01
# Epoch 73: Train=6.294e-02 | Val=2.490e-01
# Epoch 74: Train=6.914e-02 | Val=2.599e-01
# Epoch 75: Train=7.193e-02 | Val=2.683e-01
# Epoch 76: Train=6.453e-02 | Val=2.916e-01
# Epoch 77: Train=6.583e-02 | Val=2.841e-01
# Epoch 78: Train=6.341e-02 | Val=2.729e-01
# Epoch 79: Train=6.475e-02 | Val=2.728e-01
# Epoch 80: Train=5.660e-02 | Val=2.818e-01
# Epoch 81: Train=6.058e-02 | Val=2.879e-01
# Epoch 82: Train=6.193e-02 | Val=2.620e-01
# Epoch 83: Train=6.204e-02 | Val=3.912e-01
# Epoch 84: Train=6.887e-02 | Val=2.558e-01
# Epoch 85: Train=6.498e-02 | Val=2.936e-01
# Epoch 86: Train=6.127e-02 | Val=3.406e-01
# Epoch 87: Train=6.021e-02 | Val=2.764e-01
# Epoch 88: Train=6.011e-02 | Val=2.661e-01
# Epoch 89: Train=5.363e-02 | Val=2.885e-01
# Epoch 90: Train=5.435e-02 | Val=2.820e-01
# Epoch 91: Train=5.731e-02 | Val=2.732e-01
# Epoch 92: Train=5.538e-02 | Val=3.441e-01
# Epoch 93: Train=5.952e-02 | Val=2.810e-01
# Epoch 94: Train=5.070e-02 | Val=3.370e-01
# Epoch 95: Train=6.846e-02 | Val=2.749e-01
# Epoch 96: Train=8.008e-02 | Val=2.737e-01
# Epoch 97: Train=6.468e-02 | Val=2.780e-01
# Epoch 98: Train=5.503e-02 | Val=2.901e-01
# Epoch 99: Train=5.451e-02 | Val=3.469e-01
# Epoch 100: Train=5.947e-02 | Val=2.979e-01
# CNN(
#   (conv): Sequential(
#     (0): Conv3d(4, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): GroupNorm(8, 32, eps=1e-05, affine=True)
#     (2): ReLU()
#     (3): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (5): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (6): ReLU()
#     (7): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (9): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (10): ReLU()
#     (11): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (pool): AdaptiveAvgPool3d(output_size=1)
#   (fc): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
evaluate_model(
        model, te_loader, test_ds,
        y_mean, y_std,
        vlin_baseline, rho_vlin
    )
# Out:
# p68 = 33.717354
# p95 = 97.67625
# p99 = 203.43063
# ===== TEST RESULTS =====
# N = 569
# RMSE = 50.333
# RMS(true) = 96.798
# RMS(pred) = 84.554
