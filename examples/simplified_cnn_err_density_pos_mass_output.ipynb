# %%
import sys
import os
import numpy as np
import torch
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import train_test_split
from scipy.stats import pearsonr

# %%
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from kszcnn.simplified_cnn_err_density_pos_mass import *

# %%
np.random.seed(SEED)
torch.manual_seed(SEED)

# %%
#  1. Load grids
grid_train, grid_test = memmap_grid_slices(
    GRID_FILE, [TRAIN_REAL_IDX, TEST_REAL_IDX]
)

print("Grid shapes:", grid_train.shape, grid_test.shape)
# Out:
# Grid shapes: (128, 128, 128) (128, 128, 128)

# %%
# 2. Smooth density
delta_train = smooth_density_kspace(grid_train, SMOOTH_SCALE)
delta_test  = smooth_density_kspace(grid_test, SMOOTH_SCALE)

# %%
#  3. Normalize
mean = delta_train.mean()
std  = delta_train.std() + 1e-12

delta_train = (delta_train - mean) / std
delta_test  = (delta_test - mean) / std

# %%
# 4. Load halos
pos_tr, vel_tr, mass_tr = load_halos(TRAIN_HALO_FILE)
pos_te, vel_te, mass_te = load_halos(TEST_HALO_FILE)

pos_tr = redshift_err(pos_tr, sigma_z=1e-4)
pos_te = redshift_err(pos_te, sigma_z=1e-4)


print("Halos:", len(pos_tr), len(pos_te))
# Out:
# Halos: 20817 21205

# %%
#  5. Dataset 
rng = np.random.RandomState(SEED)
train_ds_full = HaloDataset(
    delta_train,
    pos_tr,
    vel_tr,
    mass_tr,
    mass_cut=MASS_CUT, max_n=MAX_HALOS,
    rng=rng
)

test_ds = HaloDataset(
    delta_test,
    pos_te,
    vel_te,
    mass_te,
    mass_cut=MASS_CUT, max_n=MAX_HALOS,
    rng=rng
)
# Out:
# Selected halos: 547
# Selected halos: 569

# %%
#  6. Linear baseline 
vlin_test = compute_vlin_from_density(
    grid_test,R_smooth=SMOOTH_SCALE
)

vlin_baseline = vlin_at_halos(vlin_test, test_ds.pos)

rho_vlin = pearsonr(test_ds.vz, vlin_baseline)[0]

print("Linear theory correlation:", rho_vlin)
# Out:
# Linear theory correlation: 0.8239114

# %%
#7. Train / validation
idxs = np.arange(len(train_ds_full))

tr_idx, val_idx = train_test_split(
    idxs,
    test_size=0.2,
    random_state=SEED
)

tr_ds  = Subset(train_ds_full, tr_idx)
val_ds = Subset(train_ds_full, val_idx)

# %%
#  8. Loaders
tr_loader = DataLoader(tr_ds, batch_size=BATCH, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH)
te_loader  = DataLoader(test_ds, batch_size=BATCH)

# %%
#  9. Normalize velocity
y_train = np.array([train_ds_full[i][1] for i in tr_idx])

y_mean = y_train.mean()
y_std  = y_train.std() + 1e-12

print("Velocity mean/std:", y_mean, y_std)
# Out:
# Velocity mean/std: -1.0862699 105.11467

# %%
model = CNN().to(DEVICE)

# %%
train_model(
        model, tr_loader, val_loader, y_mean, y_std
    )
# Out:
# Epoch 1: Train=3.482e-01 | Val=6.847e-01
# Epoch 2: Train=2.553e-01 | Val=5.228e-01
# Epoch 3: Train=2.104e-01 | Val=4.522e-01
# Epoch 4: Train=1.758e-01 | Val=4.025e-01
# Epoch 5: Train=1.778e-01 | Val=4.307e-01
# Epoch 6: Train=1.611e-01 | Val=3.534e-01
# Epoch 7: Train=1.531e-01 | Val=3.477e-01
# Epoch 8: Train=1.483e-01 | Val=4.363e-01
# Epoch 9: Train=1.437e-01 | Val=3.320e-01
# Epoch 10: Train=1.438e-01 | Val=3.669e-01
# Epoch 11: Train=1.379e-01 | Val=3.310e-01
# Epoch 12: Train=1.358e-01 | Val=4.037e-01
# Epoch 13: Train=1.485e-01 | Val=3.126e-01
# Epoch 14: Train=1.442e-01 | Val=4.063e-01
# Epoch 15: Train=1.588e-01 | Val=4.081e-01
# Epoch 16: Train=1.367e-01 | Val=3.765e-01
# Epoch 17: Train=1.322e-01 | Val=2.960e-01
# Epoch 18: Train=1.220e-01 | Val=3.063e-01
# Epoch 19: Train=1.318e-01 | Val=3.252e-01
# Epoch 20: Train=1.258e-01 | Val=2.950e-01
# Epoch 21: Train=1.156e-01 | Val=3.019e-01
# Epoch 22: Train=1.069e-01 | Val=3.105e-01
# Epoch 23: Train=1.107e-01 | Val=2.738e-01
# Epoch 24: Train=1.047e-01 | Val=3.459e-01
# Epoch 25: Train=1.156e-01 | Val=2.873e-01
# Epoch 26: Train=1.044e-01 | Val=2.958e-01
# Epoch 27: Train=1.082e-01 | Val=3.372e-01
# Epoch 28: Train=9.843e-02 | Val=3.136e-01
# Epoch 29: Train=1.035e-01 | Val=2.709e-01
# Epoch 30: Train=9.425e-02 | Val=2.729e-01
# Epoch 31: Train=1.065e-01 | Val=2.555e-01
# Epoch 32: Train=9.876e-02 | Val=3.213e-01
# Epoch 33: Train=1.130e-01 | Val=2.615e-01
# Epoch 34: Train=9.593e-02 | Val=2.850e-01
# Epoch 35: Train=9.785e-02 | Val=3.578e-01
# Epoch 36: Train=9.943e-02 | Val=3.811e-01
# Epoch 37: Train=1.105e-01 | Val=3.336e-01
# Epoch 38: Train=8.625e-02 | Val=2.663e-01
# Epoch 39: Train=9.048e-02 | Val=3.779e-01
# Epoch 40: Train=1.042e-01 | Val=2.619e-01
# Epoch 41: Train=8.819e-02 | Val=3.191e-01
# Epoch 42: Train=9.571e-02 | Val=3.552e-01
# Epoch 43: Train=1.035e-01 | Val=3.482e-01
# Epoch 44: Train=8.365e-02 | Val=3.025e-01
# Epoch 45: Train=8.823e-02 | Val=2.874e-01
# Epoch 46: Train=8.504e-02 | Val=2.584e-01
# Epoch 47: Train=7.561e-02 | Val=3.034e-01
# Epoch 48: Train=8.149e-02 | Val=3.171e-01
# Epoch 49: Train=8.230e-02 | Val=3.919e-01
# Epoch 50: Train=7.854e-02 | Val=2.834e-01
# Epoch 51: Train=7.464e-02 | Val=3.221e-01
# Epoch 52: Train=1.023e-01 | Val=2.772e-01
# Epoch 53: Train=8.673e-02 | Val=3.166e-01
# Epoch 54: Train=7.748e-02 | Val=2.825e-01
# Epoch 55: Train=7.339e-02 | Val=2.865e-01
# Epoch 56: Train=6.860e-02 | Val=3.304e-01
# Epoch 57: Train=7.564e-02 | Val=2.821e-01
# Epoch 58: Train=6.335e-02 | Val=3.067e-01
# Epoch 59: Train=6.470e-02 | Val=3.102e-01
# Epoch 60: Train=6.146e-02 | Val=3.023e-01
# Epoch 61: Train=7.776e-02 | Val=3.751e-01
# Epoch 62: Train=7.739e-02 | Val=2.807e-01
# Epoch 63: Train=6.465e-02 | Val=2.809e-01
# Epoch 64: Train=5.124e-02 | Val=3.000e-01
# Epoch 65: Train=5.901e-02 | Val=2.866e-01
# Epoch 66: Train=5.734e-02 | Val=3.782e-01
# Epoch 67: Train=7.253e-02 | Val=2.951e-01
# Epoch 68: Train=6.033e-02 | Val=2.641e-01
# Epoch 69: Train=5.652e-02 | Val=3.232e-01
# Epoch 70: Train=6.565e-02 | Val=3.107e-01
# Epoch 71: Train=5.391e-02 | Val=3.040e-01
# Epoch 72: Train=5.266e-02 | Val=3.325e-01
# Epoch 73: Train=5.758e-02 | Val=2.811e-01
# Epoch 74: Train=5.033e-02 | Val=2.864e-01
# Epoch 75: Train=5.189e-02 | Val=3.273e-01
# Epoch 76: Train=4.863e-02 | Val=3.139e-01
# Epoch 77: Train=4.892e-02 | Val=3.267e-01
# Epoch 78: Train=5.225e-02 | Val=3.255e-01
# Epoch 79: Train=4.602e-02 | Val=2.753e-01
# Epoch 80: Train=4.279e-02 | Val=3.167e-01
# Epoch 81: Train=4.491e-02 | Val=3.086e-01
# Epoch 82: Train=4.428e-02 | Val=3.257e-01
# Epoch 83: Train=5.179e-02 | Val=3.051e-01
# Epoch 84: Train=4.567e-02 | Val=3.723e-01
# Epoch 85: Train=4.325e-02 | Val=3.102e-01
# Epoch 86: Train=4.169e-02 | Val=3.264e-01
# Epoch 87: Train=4.443e-02 | Val=2.907e-01
# Epoch 88: Train=4.799e-02 | Val=4.193e-01
# Epoch 89: Train=5.757e-02 | Val=2.896e-01
# Epoch 90: Train=5.414e-02 | Val=2.977e-01
# Epoch 91: Train=4.322e-02 | Val=2.957e-01
# Epoch 92: Train=4.106e-02 | Val=2.800e-01
# Epoch 93: Train=4.862e-02 | Val=3.211e-01
# Epoch 94: Train=4.932e-02 | Val=2.735e-01
# Epoch 95: Train=4.605e-02 | Val=3.074e-01
# Epoch 96: Train=4.379e-02 | Val=3.443e-01
# Epoch 97: Train=3.676e-02 | Val=3.013e-01
# Epoch 98: Train=3.655e-02 | Val=3.072e-01
# Epoch 99: Train=5.377e-02 | Val=3.240e-01
# Epoch 100: Train=3.897e-02 | Val=2.915e-01
# CNN(
#   (conv): Sequential(
#     (0): Conv3d(5, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): GroupNorm(8, 32, eps=1e-05, affine=True)
#     (2): ReLU()
#     (3): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (5): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (6): ReLU()
#     (7): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (9): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (10): ReLU()
#     (11): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (pool): AdaptiveAvgPool3d(output_size=1)
#   (fc): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
evaluate_model(
        model, te_loader, test_ds,
        y_mean, y_std,
        vlin_baseline, rho_vlin
    )
# Out:
# p68 = 35.324688
# p95 = 100.278206
# p99 = 180.0423
# ===== TEST RESULTS =====
# N = 569
# RMSE = 51.874
# RMS(true) = 96.798
# RMS(pred) = 93.702
