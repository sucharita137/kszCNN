# %%
import sys
import os
import numpy as np
import torch
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import train_test_split
from scipy.stats import pearsonr

# %%
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from kszcnn.simplified_cnn_density_pos_mass import *

# %%
np.random.seed(SEED)
torch.manual_seed(SEED)

# %%
#  1. Load grids
grid_train, grid_test = memmap_grid_slices(
    GRID_FILE, [TRAIN_REAL_IDX, TEST_REAL_IDX]
)

print("Grid shapes:", grid_train.shape, grid_test.shape)
# Out:
# Grid shapes: (128, 128, 128) (128, 128, 128)

# %%
# 2. Smooth density
delta_train = smooth_density_kspace(grid_train, SMOOTH_SCALE)
delta_test  = smooth_density_kspace(grid_test, SMOOTH_SCALE)

# %%
#  3. Normalize
mean = delta_train.mean()
std  = delta_train.std() + 1e-12

delta_train = (delta_train - mean) / std
delta_test  = (delta_test - mean) / std

# %%
# 4. Load halos
pos_tr, vel_tr, mass_tr = load_halos(TRAIN_HALO_FILE)
pos_te, vel_te, mass_te = load_halos(TEST_HALO_FILE)

print("Halos:", len(pos_tr), len(pos_te))
# Out:
# Halos: 20817 21205

# %%
#  5. Dataset 
rng = np.random.RandomState(SEED)
train_ds_full = HaloDataset(
    delta_train,
    pos_tr,
    vel_tr,
    mass_tr,
    mass_cut=MASS_CUT, max_n=MAX_HALOS,
    rng=rng
)

test_ds = HaloDataset(
    delta_test,
    pos_te,
    vel_te,
    mass_te,
    mass_cut=MASS_CUT, max_n=MAX_HALOS,
    rng=rng
)
# Out:
# Selected halos: 547
# Selected halos: 569

# %%
#  6. Linear baseline 
vlin_test = compute_vlin_from_density(
    grid_test,R_smooth=SMOOTH_SCALE
)

vlin_baseline = vlin_at_halos(vlin_test, test_ds.pos)

rho_vlin = pearsonr(test_ds.vz, vlin_baseline)[0]

print("Linear theory correlation:", rho_vlin)
# Out:
# Linear theory correlation: 0.8551195

# %%
#7. Train / validation
idxs = np.arange(len(train_ds_full))

tr_idx, val_idx = train_test_split(
    idxs,
    test_size=0.2,
    random_state=SEED
)

tr_ds  = Subset(train_ds_full, tr_idx)
val_ds = Subset(train_ds_full, val_idx)

# %%
#  8. Loaders
tr_loader = DataLoader(tr_ds, batch_size=BATCH, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH)
te_loader  = DataLoader(test_ds, batch_size=BATCH)

# %%
#  9. Normalize velocity
y_train = np.array([train_ds_full[i][1] for i in tr_idx])

y_mean = y_train.mean()
y_std  = y_train.std() + 1e-12

print("Velocity mean/std:", y_mean, y_std)
# Out:
# Velocity mean/std: -1.0862699 105.11467

# %%
model = CNN().to(DEVICE)

# %%
train_model(
        model, tr_loader, val_loader, y_mean, y_std
    )
# Out:
# Epoch 1: Train=3.477e-01 | Val=6.696e-01
# Epoch 2: Train=2.448e-01 | Val=5.735e-01
# Epoch 3: Train=2.017e-01 | Val=4.769e-01
# Epoch 4: Train=1.703e-01 | Val=3.679e-01
# Epoch 5: Train=1.754e-01 | Val=4.009e-01
# Epoch 6: Train=1.564e-01 | Val=3.283e-01
# Epoch 7: Train=1.496e-01 | Val=3.270e-01
# Epoch 8: Train=1.427e-01 | Val=4.200e-01
# Epoch 9: Train=1.377e-01 | Val=2.903e-01
# Epoch 10: Train=1.390e-01 | Val=2.963e-01
# Epoch 11: Train=1.266e-01 | Val=2.693e-01
# Epoch 12: Train=1.254e-01 | Val=3.360e-01
# Epoch 13: Train=1.472e-01 | Val=2.579e-01
# Epoch 14: Train=1.324e-01 | Val=2.840e-01
# Epoch 15: Train=1.404e-01 | Val=3.109e-01
# Epoch 16: Train=1.208e-01 | Val=3.018e-01
# Epoch 17: Train=1.195e-01 | Val=2.453e-01
# Epoch 18: Train=1.112e-01 | Val=3.234e-01
# Epoch 19: Train=1.226e-01 | Val=2.665e-01
# Epoch 20: Train=1.159e-01 | Val=2.505e-01
# Epoch 21: Train=1.089e-01 | Val=2.829e-01
# Epoch 22: Train=1.015e-01 | Val=2.416e-01
# Epoch 23: Train=1.095e-01 | Val=2.342e-01
# Epoch 24: Train=1.031e-01 | Val=2.767e-01
# Epoch 25: Train=1.072e-01 | Val=2.248e-01
# Epoch 26: Train=9.483e-02 | Val=2.433e-01
# Epoch 27: Train=9.589e-02 | Val=2.279e-01
# Epoch 28: Train=1.051e-01 | Val=2.488e-01
# Epoch 29: Train=1.039e-01 | Val=2.368e-01
# Epoch 30: Train=9.049e-02 | Val=2.135e-01
# Epoch 31: Train=1.020e-01 | Val=1.965e-01
# Epoch 32: Train=9.177e-02 | Val=2.716e-01
# Epoch 33: Train=1.103e-01 | Val=2.334e-01
# Epoch 34: Train=9.151e-02 | Val=2.150e-01
# Epoch 35: Train=8.864e-02 | Val=2.590e-01
# Epoch 36: Train=9.826e-02 | Val=2.829e-01
# Epoch 37: Train=9.453e-02 | Val=2.402e-01
# Epoch 38: Train=7.855e-02 | Val=2.134e-01
# Epoch 39: Train=8.298e-02 | Val=2.836e-01
# Epoch 40: Train=8.963e-02 | Val=2.161e-01
# Epoch 41: Train=7.859e-02 | Val=2.022e-01
# Epoch 42: Train=8.631e-02 | Val=2.940e-01
# Epoch 43: Train=9.887e-02 | Val=2.551e-01
# Epoch 44: Train=7.850e-02 | Val=2.478e-01
# Epoch 45: Train=8.355e-02 | Val=2.453e-01
# Epoch 46: Train=8.397e-02 | Val=2.156e-01
# Epoch 47: Train=7.151e-02 | Val=2.272e-01
# Epoch 48: Train=7.253e-02 | Val=2.339e-01
# Epoch 49: Train=7.543e-02 | Val=2.657e-01
# Epoch 50: Train=7.007e-02 | Val=2.142e-01
# Epoch 51: Train=7.409e-02 | Val=2.418e-01
# Epoch 52: Train=8.446e-02 | Val=2.399e-01
# Epoch 53: Train=8.749e-02 | Val=2.660e-01
# Epoch 54: Train=8.467e-02 | Val=2.245e-01
# Epoch 55: Train=8.103e-02 | Val=2.569e-01
# Epoch 56: Train=6.519e-02 | Val=2.095e-01
# Epoch 57: Train=6.008e-02 | Val=2.488e-01
# Epoch 58: Train=5.823e-02 | Val=2.435e-01
# Epoch 59: Train=6.725e-02 | Val=3.064e-01
# Epoch 60: Train=6.008e-02 | Val=2.478e-01
# Epoch 61: Train=5.799e-02 | Val=2.313e-01
# Epoch 62: Train=7.202e-02 | Val=2.305e-01
# Epoch 63: Train=6.001e-02 | Val=2.522e-01
# Epoch 64: Train=5.810e-02 | Val=2.253e-01
# Epoch 65: Train=5.479e-02 | Val=2.147e-01
# Epoch 66: Train=5.307e-02 | Val=3.027e-01
# Epoch 67: Train=7.029e-02 | Val=2.341e-01
# Epoch 68: Train=6.777e-02 | Val=2.654e-01
# Epoch 69: Train=6.174e-02 | Val=2.525e-01
# Epoch 70: Train=6.295e-02 | Val=2.614e-01
# Epoch 71: Train=4.609e-02 | Val=2.385e-01
# Epoch 72: Train=4.247e-02 | Val=2.360e-01
# Epoch 73: Train=4.915e-02 | Val=2.283e-01
# Epoch 74: Train=4.042e-02 | Val=2.257e-01
# Epoch 75: Train=4.623e-02 | Val=2.456e-01
# Epoch 76: Train=4.048e-02 | Val=2.734e-01
# Epoch 77: Train=4.166e-02 | Val=2.453e-01
# Epoch 78: Train=4.164e-02 | Val=2.259e-01
# Epoch 79: Train=3.849e-02 | Val=2.257e-01
# Epoch 80: Train=3.376e-02 | Val=2.463e-01
# Epoch 81: Train=3.891e-02 | Val=2.872e-01
# Epoch 82: Train=3.687e-02 | Val=2.462e-01
# Epoch 83: Train=3.541e-02 | Val=2.373e-01
# Epoch 84: Train=4.292e-02 | Val=2.622e-01
# Epoch 85: Train=4.033e-02 | Val=2.437e-01
# Epoch 86: Train=3.290e-02 | Val=2.450e-01
# Epoch 87: Train=3.148e-02 | Val=2.400e-01
# Epoch 88: Train=3.390e-02 | Val=2.468e-01
# Epoch 89: Train=3.226e-02 | Val=2.568e-01
# Epoch 90: Train=4.305e-02 | Val=2.653e-01
# Epoch 91: Train=4.179e-02 | Val=2.591e-01
# Epoch 92: Train=3.746e-02 | Val=2.536e-01
# Epoch 93: Train=4.313e-02 | Val=2.448e-01
# Epoch 94: Train=4.130e-02 | Val=2.626e-01
# Epoch 95: Train=3.763e-02 | Val=2.367e-01
# Epoch 96: Train=3.080e-02 | Val=2.375e-01
# Epoch 97: Train=2.903e-02 | Val=2.539e-01
# Epoch 98: Train=2.846e-02 | Val=2.592e-01
# Epoch 99: Train=4.954e-02 | Val=2.345e-01
# Epoch 100: Train=4.151e-02 | Val=2.284e-01
# CNN(
#   (conv): Sequential(
#     (0): Conv3d(5, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): GroupNorm(8, 32, eps=1e-05, affine=True)
#     (2): ReLU()
#     (3): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (5): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (6): ReLU()
#     (7): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (9): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (10): ReLU()
#     (11): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (pool): AdaptiveAvgPool3d(output_size=1)
#   (fc): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
evaluate_model(
        model, te_loader, test_ds,
        y_mean, y_std,
        vlin_baseline, rho_vlin
    )
# Out:
# ===== TEST RESULTS =====
# N = 569
# RMSE = 45.294
# RMS(true) = 96.798
# RMS(pred) = 90.212
