# %%
import sys
import os
import numpy as np
import torch
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import train_test_split
from scipy.stats import pearsonr

# %%
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from kszcnn.simplified_cnn_pos_mass import *

# %%
np.random.seed(SEED)
torch.manual_seed(SEED)

# %%
#  1. Load grids
grid_train, grid_test = memmap_grid_slices(
    GRID_FILE, [TRAIN_REAL_IDX, TEST_REAL_IDX]
)

print("Grid shapes:", grid_train.shape, grid_test.shape)
# Out:
# Grid shapes: (128, 128, 128) (128, 128, 128)

# %%
# 2. Smooth density
delta_train = smooth_density_kspace(grid_train, SMOOTH_SCALE)
delta_test  = smooth_density_kspace(grid_test, SMOOTH_SCALE)

# %%
#  3. Normalize
mean = delta_train.mean()
std  = delta_train.std() + 1e-12

delta_train = (delta_train - mean) / std
delta_test  = (delta_test - mean) / std

# %%
# 4. Load halos
pos_tr, vel_tr, mass_tr = load_halos(TRAIN_HALO_FILE)
pos_te, vel_te, mass_te = load_halos(TEST_HALO_FILE)

print("Halos:", len(pos_tr), len(pos_te))
# Out:
# Halos: 20817 21205

# %%
#  5. Dataset 
rng = np.random.RandomState(SEED)
train_ds_full = HaloDataset(
    delta_train,
    pos_tr,
    vel_tr,
    mass_tr,
    mass_cut=MASS_CUT, max_n=MAX_HALOS,
    rng=rng
)

test_ds = HaloDataset(
    delta_test,
    pos_te,
    vel_te,
    mass_te,
    mass_cut=MASS_CUT, max_n=MAX_HALOS,
    rng=rng
)
# Out:
# Selected halos: 547
# Selected halos: 569

# %%
#  6. Linear baseline 
vlin_test = compute_vlin_from_density(
    grid_test,R_smooth=SMOOTH_SCALE
)

vlin_baseline = vlin_at_halos(vlin_test, test_ds.pos)

rho_vlin = pearsonr(test_ds.vz, vlin_baseline)[0]

print("Linear theory correlation:", rho_vlin)
# Out:
# Linear theory correlation: 0.8551195

# %%
#7. Train / validation
idxs = np.arange(len(train_ds_full))

tr_idx, val_idx = train_test_split(
    idxs,
    test_size=0.2,
    random_state=SEED
)

tr_ds  = Subset(train_ds_full, tr_idx)
val_ds = Subset(train_ds_full, val_idx)

# %%
#  8. Loaders
tr_loader = DataLoader(tr_ds, batch_size=BATCH, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH)
te_loader  = DataLoader(test_ds, batch_size=BATCH)

# %%
#  9. Normalize velocity
y_train = np.array([train_ds_full[i][1] for i in tr_idx])

y_mean = y_train.mean()
y_std  = y_train.std() + 1e-12

print("Velocity mean/std:", y_mean, y_std)
# Out:
# Velocity mean/std: -1.0862699 105.11467

# %%
model = CNN().to(DEVICE)

# %%
train_model(
        model, tr_loader, val_loader, y_mean, y_std
    )
# Out:
# Epoch 1: Train=3.570e-01 | Val=8.128e-01
# Epoch 2: Train=3.092e-01 | Val=7.587e-01
# Epoch 3: Train=2.881e-01 | Val=7.295e-01
# Epoch 4: Train=2.827e-01 | Val=8.965e-01
# Epoch 5: Train=2.811e-01 | Val=7.069e-01
# Epoch 6: Train=2.699e-01 | Val=8.094e-01
# Epoch 7: Train=2.623e-01 | Val=6.200e-01
# Epoch 8: Train=2.271e-01 | Val=7.149e-01
# Epoch 9: Train=2.452e-01 | Val=6.372e-01
# Epoch 10: Train=2.359e-01 | Val=6.261e-01
# Epoch 11: Train=2.283e-01 | Val=6.419e-01
# Epoch 12: Train=2.072e-01 | Val=6.881e-01
# Epoch 13: Train=2.165e-01 | Val=5.756e-01
# Epoch 14: Train=1.981e-01 | Val=6.220e-01
# Epoch 15: Train=2.043e-01 | Val=5.283e-01
# Epoch 16: Train=1.876e-01 | Val=7.278e-01
# Epoch 17: Train=1.968e-01 | Val=4.958e-01
# Epoch 18: Train=1.967e-01 | Val=7.891e-01
# Epoch 19: Train=2.036e-01 | Val=6.616e-01
# Epoch 20: Train=2.039e-01 | Val=5.765e-01
# Epoch 21: Train=1.771e-01 | Val=6.783e-01
# Epoch 22: Train=1.750e-01 | Val=4.896e-01
# Epoch 23: Train=1.680e-01 | Val=5.144e-01
# Epoch 24: Train=1.734e-01 | Val=5.176e-01
# Epoch 25: Train=1.616e-01 | Val=6.381e-01
# Epoch 26: Train=1.798e-01 | Val=4.855e-01
# Epoch 27: Train=1.769e-01 | Val=4.964e-01
# Epoch 28: Train=1.712e-01 | Val=5.384e-01
# Epoch 29: Train=1.744e-01 | Val=4.856e-01
# Epoch 30: Train=1.577e-01 | Val=5.217e-01
# Epoch 31: Train=1.665e-01 | Val=5.202e-01
# Epoch 32: Train=1.607e-01 | Val=5.298e-01
# Epoch 33: Train=1.464e-01 | Val=4.389e-01
# Epoch 34: Train=1.436e-01 | Val=7.047e-01
# Epoch 35: Train=1.602e-01 | Val=5.401e-01
# Epoch 36: Train=1.515e-01 | Val=4.813e-01
# Epoch 37: Train=1.421e-01 | Val=4.731e-01
# Epoch 38: Train=1.363e-01 | Val=4.690e-01
# Epoch 39: Train=1.470e-01 | Val=4.723e-01
# Epoch 40: Train=1.660e-01 | Val=5.595e-01
# Epoch 41: Train=1.439e-01 | Val=5.263e-01
# Epoch 42: Train=1.575e-01 | Val=4.134e-01
# Epoch 43: Train=1.340e-01 | Val=4.221e-01
# Epoch 44: Train=1.371e-01 | Val=4.053e-01
# Epoch 45: Train=1.250e-01 | Val=4.465e-01
# Epoch 46: Train=1.212e-01 | Val=5.936e-01
# Epoch 47: Train=1.350e-01 | Val=4.548e-01
# Epoch 48: Train=1.239e-01 | Val=4.540e-01
# Epoch 49: Train=1.323e-01 | Val=4.216e-01
# Epoch 50: Train=1.227e-01 | Val=4.091e-01
# Epoch 51: Train=1.144e-01 | Val=4.022e-01
# Epoch 52: Train=1.144e-01 | Val=4.478e-01
# Epoch 53: Train=1.248e-01 | Val=4.981e-01
# Epoch 54: Train=1.256e-01 | Val=3.965e-01
# Epoch 55: Train=1.206e-01 | Val=4.566e-01
# Epoch 56: Train=1.136e-01 | Val=3.768e-01
# Epoch 57: Train=1.205e-01 | Val=4.391e-01
# Epoch 58: Train=1.100e-01 | Val=3.820e-01
# Epoch 59: Train=1.010e-01 | Val=4.736e-01
# Epoch 60: Train=1.136e-01 | Val=4.677e-01
# Epoch 61: Train=1.242e-01 | Val=4.370e-01
# Epoch 62: Train=1.084e-01 | Val=4.162e-01
# Epoch 63: Train=1.018e-01 | Val=3.868e-01
# Epoch 64: Train=1.000e-01 | Val=3.957e-01
# Epoch 65: Train=1.034e-01 | Val=4.347e-01
# Epoch 66: Train=1.294e-01 | Val=4.037e-01
# Epoch 67: Train=1.073e-01 | Val=4.200e-01
# Epoch 68: Train=1.088e-01 | Val=4.859e-01
# Epoch 69: Train=1.051e-01 | Val=3.751e-01
# Epoch 70: Train=9.502e-02 | Val=3.951e-01
# Epoch 71: Train=9.029e-02 | Val=5.121e-01
# Epoch 72: Train=9.189e-02 | Val=4.287e-01
# Epoch 73: Train=8.324e-02 | Val=3.702e-01
# Epoch 74: Train=9.074e-02 | Val=4.315e-01
# Epoch 75: Train=9.233e-02 | Val=4.498e-01
# Epoch 76: Train=9.401e-02 | Val=4.215e-01
# Epoch 77: Train=9.699e-02 | Val=7.203e-01
# Epoch 78: Train=9.376e-02 | Val=3.880e-01
# Epoch 79: Train=7.990e-02 | Val=5.625e-01
# Epoch 80: Train=7.928e-02 | Val=3.847e-01
# Epoch 81: Train=8.219e-02 | Val=3.845e-01
# Epoch 82: Train=7.095e-02 | Val=3.584e-01
# Epoch 83: Train=6.839e-02 | Val=3.703e-01
# Epoch 84: Train=7.929e-02 | Val=4.570e-01
# Epoch 85: Train=7.702e-02 | Val=4.340e-01
# Epoch 86: Train=7.376e-02 | Val=4.441e-01
# Epoch 87: Train=7.241e-02 | Val=3.918e-01
# Epoch 88: Train=7.180e-02 | Val=4.226e-01
# Epoch 89: Train=6.729e-02 | Val=3.635e-01
# Epoch 90: Train=7.191e-02 | Val=3.446e-01
# Epoch 91: Train=6.187e-02 | Val=3.881e-01
# Epoch 92: Train=7.803e-02 | Val=3.733e-01
# Epoch 93: Train=7.627e-02 | Val=5.145e-01
# Epoch 94: Train=8.313e-02 | Val=3.684e-01
# Epoch 95: Train=7.474e-02 | Val=3.538e-01
# Epoch 96: Train=9.604e-02 | Val=4.299e-01
# Epoch 97: Train=9.720e-02 | Val=4.601e-01
# Epoch 98: Train=8.672e-02 | Val=3.885e-01
# Epoch 99: Train=9.016e-02 | Val=3.732e-01
# Epoch 100: Train=7.384e-02 | Val=3.625e-01
# CNN(
#   (conv): Sequential(
#     (0): Conv3d(4, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): GroupNorm(8, 32, eps=1e-05, affine=True)
#     (2): ReLU()
#     (3): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (5): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (6): ReLU()
#     (7): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (9): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (10): ReLU()
#     (11): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (pool): AdaptiveAvgPool3d(output_size=1)
#   (fc): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
evaluate_model(
        model, te_loader, test_ds,
        y_mean, y_std,
        vlin_baseline, rho_vlin
    )
# Out:
# ===== TEST RESULTS =====
# N = 569
# RMSE = 61.019
# RMS(true) = 96.798
# RMS(pred) = 87.530
